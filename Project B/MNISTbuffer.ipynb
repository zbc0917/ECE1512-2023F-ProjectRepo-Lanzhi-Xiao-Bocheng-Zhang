# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install kornia
import os
import argparse
import torch
import torch.nn as nn

from tqdm import tqdm
import kornia as K
from torchvision import datasets, transforms
import sys
sys.path.append('/content/drive/MyDrive/ECE1512/ProjectB')
import utils
from utils import get_network, get_daparam, TensorDataset, ParamDiffAug
import copy

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
# Out:
# Requirement already satisfied: kornia in /usr/local/lib/python3.10/dist-packages (0.7.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from kornia) (23.2)
# Requirement already satisfied: torch>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from kornia) (2.1.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.1->kornia) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.1->kornia) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.1->kornia) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.1->kornia) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.1->kornia) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.1->kornia) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.1->kornia) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.9.1->kornia) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.9.1->kornia) (1.3.0)

# %%
import numpy as np

# %%
#https://github.com/GzyAftermath/DATM/blob/main/utils/utils_baseline.py
"""
@misc{guo2023lossless,
  title={Towards Lossless Dataset Distillation via Difficulty-Aligned Trajectory Matching},
  author={Ziyao Guo and Kai Wang and George Cazenavette and Hui Li and Kaipeng Zhang and Yang You},
  year={2023},
  eprint={2310.05773},
  archivePrefix={arXiv},
  primaryClass={cs.CV}
}
"""

def get_dataset(dataset, data_path, batch_size=1, subset="imagenette", args=None, baseline=False):

  class_map = None
  loader_train_dict = None
  class_map_inv = None

  channel = 1
  im_size = (28, 28)
  num_classes = 10
  mean = [0.1307]
  std = [0.3081]
  if not args.zca:
    transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize(mean=mean, std=std)])
  else:
    transform = transforms.Compose([transforms.ToTensor()])
  dst_train = datasets.MNIST(data_path, train=True, download=True, transform=transform) # no augmentation
  dst_test = datasets.MNIST(data_path, train=False, download=True, transform=transform)
  class_names = [str(c) for c in range(num_classes)]
  class_map = {x:x for x in range(num_classes)}

  if args.zca:
    images = []
    labels = []
    print("Train ZCA")
    for i in tqdm.tqdm(range(len(dst_train))):
        im, lab = dst_train[i]
        images.append(im)
        labels.append(lab)
    images = torch.stack(images, dim=0).to(args.device)
    labels = torch.tensor(labels, dtype=torch.long, device="cpu")
    zca = K.enhance.ZCAWhitening(eps=0.1, compute_inv=True)
    zca.fit(images)
    zca_images = zca(images).to("cpu")
    dst_train = TensorDataset(zca_images, labels)

    images = []
    labels = []
    print("Test ZCA")
    for i in tqdm.tqdm(range(len(dst_test))):
        im, lab = dst_test[i]
        images.append(im)
        labels.append(lab)
    images = torch.stack(images, dim=0).to(args.device)
    labels = torch.tensor(labels, dtype=torch.long, device="cpu")

    zca_images = zca(images).to("cpu")
    dst_test = TensorDataset(zca_images, labels)

    print(type(zca))


    args.zca_trans = zca


  testloader = torch.utils.data.DataLoader(dst_test, batch_size=256, shuffle=False, num_workers=2)


  return channel, im_size, num_classes, class_names, mean, std, dst_train, dst_test, testloader, loader_train_dict, class_map, class_map_inv

# %%
import torch
import contextlib
from torch.distributed import ReduceOp
import torch
import torch.nn as nn
from torch.nn.modules.batchnorm import _BatchNorm

def disable_running_stats(model):
    def _disable(module):
        if isinstance(module, _BatchNorm):
            module.backup_momentum = module.momentum
            module.momentum = 0

    model.apply(_disable)

def enable_running_stats(model):
    def _enable(module):
        if isinstance(module, _BatchNorm) and hasattr(module, "backup_momentum"):
            module.momentum = module.backup_momentum

    model.apply(_enable)

class GSAM(torch.optim.Optimizer):
    def __init__(self, params, base_optimizer, model, gsam_alpha, rho_scheduler, adaptive=False, perturb_eps=1e-12, grad_reduce='mean', **kwargs):
        defaults = dict(adaptive=adaptive, **kwargs)
        super(GSAM, self).__init__(params, defaults)
        self.model = model
        self.base_optimizer = base_optimizer
        self.param_groups = self.base_optimizer.param_groups
        self.adaptive = adaptive
        self.rho_scheduler = rho_scheduler
        self.perturb_eps = perturb_eps
        self.alpha = gsam_alpha

        # initialize self.rho_t
        self.update_rho_t()

        # set up reduction for gradient across workers
        if grad_reduce.lower() == 'mean':
            if hasattr(ReduceOp, 'AVG'):
                self.grad_reduce = ReduceOp.AVG
                self.manual_average = False
            else: # PyTorch <= 1.11.0 does not have AVG, need to manually average across processes
                self.grad_reduce = ReduceOp.SUM
                self.manual_average = True
        elif grad_reduce.lower() == 'sum':
            self.grad_reduce = ReduceOp.SUM
            self.manual_average = False
        else:
            raise ValueError('"grad_reduce" should be one of ["mean", "sum"].')

    @torch.no_grad()
    def update_rho_t(self):
        self.rho_t = self.rho_scheduler.step()
        return self.rho_t

    @torch.no_grad()
    def perturb_weights(self, rho=0.0):
        grad_norm = self._grad_norm( weight_adaptive = self.adaptive )
        for group in self.param_groups:
            scale = rho / (grad_norm + self.perturb_eps)

            for p in group["params"]:
                if p.grad is None: continue
                self.state[p]["old_g"] = p.grad.data.clone()
                e_w = p.grad * scale.to(p)
                if self.adaptive:
                    e_w *= torch.pow(p, 2)
                p.add_(e_w)  # climb to the local maximum "w + e(w)"
                self.state[p]['e_w'] = e_w

    @torch.no_grad()
    def unperturb(self):
        for group in self.param_groups:
            for p in group['params']:
                if 'e_w' in self.state[p].keys():
                    p.data.sub_(self.state[p]['e_w'])

    @torch.no_grad()
    def gradient_decompose(self, alpha=0.0):
        # calculate inner product
        inner_prod = 0.0
        for group in self.param_groups:
            for p in group['params']:
                if p.grad is None: continue
                inner_prod += torch.sum(
                    self.state[p]['old_g'] * p.grad.data
                )

        # get norm
        new_grad_norm = self._grad_norm()
        old_grad_norm = self._grad_norm(by='old_g')

        # get cosine
        cosine = inner_prod / (new_grad_norm * old_grad_norm + self.perturb_eps)

        # gradient decomposition
        for group in self.param_groups:
            for p in group['params']:
                if p.grad is None: continue
                vertical = self.state[p]['old_g'] - cosine * old_grad_norm * p.grad.data / (new_grad_norm + self.perturb_eps)
                p.grad.data.add_( vertical, alpha=-alpha)

    @torch.no_grad()
    def _sync_grad(self):
        if torch.distributed.is_initialized(): # synchronize final gardients
            for group in self.param_groups:
                for p in group['params']:
                    if p.grad is None: continue
                    if self.manual_average:
                        torch.distributed.all_reduce(p.grad, op=self.grad_reduce)
                        world_size = torch.distributed.get_world_size()
                        p.grad.div_(float(world_size))
                    else:
                        torch.distributed.all_reduce(p.grad, op=self.grad_reduce)
        return

    @torch.no_grad()
    def _grad_norm(self, by=None, weight_adaptive=False):
        #shared_device = self.param_groups[0]["params"][0].device  # put everything on the same device, in case of model parallelism
        if not by:
            norm = torch.norm(
                    torch.stack([
                        ( (torch.abs(p.data) if weight_adaptive else 1.0) *  p.grad).norm(p=2)
                        for group in self.param_groups for p in group["params"]
                        if p.grad is not None
                    ]),
                    p=2
               )
        else:
            norm = torch.norm(
                torch.stack([
                    ( (torch.abs(p.data) if weight_adaptive else 1.0) * self.state[p][by]).norm(p=2)
                    for group in self.param_groups for p in group["params"]
                    if p.grad is not None
                ]),
                p=2
            )
        return norm

    def load_state_dict(self, state_dict):
        super().load_state_dict(state_dict)
        self.base_optimizer.param_groups = self.param_groups

    def maybe_no_sync(self):
        if torch.distributed.is_initialized():
            return self.model.no_sync()
        else:
            return contextlib.ExitStack()

    @torch.no_grad()
    def set_closure(self, loss_fn, inputs, targets, **kwargs):
        # create self.forward_backward_func, which is a function such that
        # self.forward_backward_func() automatically performs forward and backward passes.
        # This function does not take any arguments, and the inputs and targets data
        # should be pre-set in the definition of partial-function

        def get_grad():
            self.base_optimizer.zero_grad()
            with torch.enable_grad():
                outputs = self.model(inputs)
                loss = loss_fn(outputs, targets, **kwargs)
            loss_value = loss.data.clone().detach()
            loss.backward()
            return outputs, loss_value

        self.forward_backward_func = get_grad

    @torch.no_grad()
    def step(self, closure=None):

        if closure:
            get_grad = closure
        else:
            get_grad = self.forward_backward_func

        with self.maybe_no_sync():
            # get gradient
            outputs, loss_value = get_grad()

            # perturb weights
            self.perturb_weights(rho=self.rho_t)

            # disable running stats for second pass
            disable_running_stats(self.model)

            # get gradient at perturbed weights
            get_grad()

            # decompose and get new update direction
            self.gradient_decompose(self.alpha)

            # unperturb
            self.unperturb()

        # synchronize gradients across workers
        self._sync_grad()

        # update with new directions
        self.base_optimizer.step()

        # enable running stats
        enable_running_stats(self.model)

        return outputs, loss_value

# %%
class ProportionScheduler:
    def __init__(self, pytorch_lr_scheduler, max_lr, min_lr, max_value, min_value):
        """
        This scheduler outputs a value that evolves proportional to pytorch_lr_scheduler, e.g.
        (value - min_value) / (max_value - min_value) = (lr - min_lr) / (max_lr - min_lr)
        """
        self.t = 0
        self.pytorch_lr_scheduler = pytorch_lr_scheduler
        self.max_lr = max_lr
        self.min_lr = min_lr
        self.max_value = max_value
        self.min_value = min_value

        assert (max_lr > min_lr) or ((max_lr==min_lr) and (max_value==min_value)), "Current scheduler for `value` is scheduled to evolve proportionally to `lr`," \
        "e.g. `(lr - min_lr) / (max_lr - min_lr) = (value - min_value) / (max_value - min_value)`. Please check `max_lr >= min_lr` and `max_value >= min_value`;" \
        "if `max_lr==min_lr` hence `lr` is constant with step, please set 'max_value == min_value' so 'value' is constant with step."

        assert max_value >= min_value

        self.step() # take 1 step during initialization to get self._last_lr

    def lr(self):
        return self._last_lr[0]

    def step(self):
        self.t += 1
        if hasattr(self.pytorch_lr_scheduler, "_last_lr"):
            lr = self.pytorch_lr_scheduler._last_lr[0]
        else:
            lr = self.pytorch_lr_scheduler.optimizer.param_groups[0]['lr']

        if self.max_lr > self.min_lr:
            value = self.min_value + (self.max_value - self.min_value) * (lr - self.min_lr) / (self.max_lr - self.min_lr)
        else:
            value = self.max_value

        self._last_lr = [value]
        return value
class SchedulerBase:
    def __init__(self, T_max, max_value, min_value=0.0, init_value=0.0, warmup_steps=0, optimizer=None):
        super(SchedulerBase, self).__init__()
        self.t = 0
        self.min_value = min_value
        self.max_value = max_value
        self.init_value = init_value
        self.warmup_steps = warmup_steps
        self.total_steps = T_max

        # record current value in self._last_lr to match API from torch.optim.lr_scheduler
        self._last_lr = [init_value]

        # If optimizer is not None, will set learning rate to all trainable parameters in optimizer.
        # If optimizer is None, only output the value of lr.
        self.optimizer = optimizer

    def step(self):
        if self.t < self.warmup_steps:
            value = self.init_value + (self.max_value - self.init_value) * self.t / self.warmup_steps
        elif self.t == self.warmup_steps:
            value = self.max_value
        else:
            value = self.step_func()
        self.t += 1

        # apply the lr to optimizer if it's provided
        if self.optimizer is not None:
            for param_group in self.optimizer.param_groups:
                param_group['lr'] = value

        self._last_lr = [value]
        return value

    def step_func(self):
        pass

    def lr(self):
        return self._last_lr[0]

class LinearScheduler(SchedulerBase):
    def step_func(self):
        value = self.max_value + (self.min_value - self.max_value) * (self.t - self.warmup_steps) / (
                    self.total_steps - self.warmup_steps)
        return value

class CosineScheduler(SchedulerBase):
    def step_func(self):
        phase = (self.t-self.warmup_steps) / (self.total_steps-self.warmup_steps) * math.pi
        value = self.min_value + (self.max_value-self.min_value) * (np.cos(phase) + 1.) / 2.0
        return value

class PolyScheduler(SchedulerBase):
    def __init__(self, poly_order=-0.5, *args, **kwargs):
        super(PolyScheduler, self).__init__(*args, **kwargs)
        self.poly_order = poly_order
        assert poly_order<=0, "Please check poly_order<=0 so that the scheduler decreases with steps"

    def step_func(self):
        value = self.min_value + (self.max_value-self.min_value) * (self.t - self.warmup_steps)**self.poly_order
        return value

# %%
def epoch(mode, dataloader, net, optimizer, criterion, args, aug,scheduler, texture=False):
    loss_avg, acc_avg, num_exp = 0, 0, 0
    net = net.to(args.device)

    if mode == 'train':
        net.train()
    else:
        net.eval()

    for i_batch, datum in enumerate(dataloader):
        img = datum[0].float().to(args.device)
        lab = datum[1].long().to(args.device)

        if mode == "train" and texture:
            img = torch.cat([torch.stack([torch.roll(im, (torch.randint(args.im_size[0]*args.canvas_size, (1,)), torch.randint(args.im_size[0]*args.canvas_size, (1,))), (1,2))[:,:args.im_size[0],:args.im_size[1]] for im in img]) for _ in range(args.canvas_samples)])
            lab = torch.cat([lab for _ in range(args.canvas_samples)])

        if aug:
            if args.dsa:
                img = utils.DiffAugment(img, args.dsa_strategy, param=args.dsa_param)
            else:
                img = utils.augment(img, args.dc_aug_param, device=args.device)


        n_b = lab.shape[0]

        ##GSAM
        if mode == 'train':
            def loss_fn(predictions, targets):
                #return smooth_crossentropy(predictions, targets,smoothing=args.label_smoothing).mean()
                return criterion(predictions, targets)

            optimizer.set_closure(loss_fn, img, lab)
            output, loss = optimizer.step()
            #print(loss)

            with torch.no_grad():
                acc = np.sum(np.equal(np.argmax(output.cpu().data.numpy(), axis=-1), lab.cpu().data.numpy()))
                loss_avg += loss.item()*n_b
                acc_avg += acc
                num_exp += n_b

                scheduler.step()
                optimizer.update_rho_t()
        else:
            with torch.no_grad():
                output = net(img)
                #loss = smooth_crossentropy(output, lab)
                loss = criterion(output, lab)
                acc = np.sum(np.equal(np.argmax(output.cpu().data.numpy(), axis=-1), lab.cpu().data.numpy()))
                loss_avg += loss.item()*n_b
                acc_avg += acc
                num_exp += n_b


    loss_avg /= num_exp
    acc_avg /= num_exp

    return loss_avg, acc_avg

# %%
#https://github.com/GzyAftermath/DATM/blob/main/buffer/buffer_FTD.py

def main(args):

    args.dsa = True if args.dsa == 'True' else False
    args.device = 'cuda' if torch.cuda.is_available() else 'cpu'
    args.dsa_param = ParamDiffAug()

    channel, im_size, num_classes, class_names, mean, std, dst_train, dst_test, testloader, loader_train_dict, class_map, class_map_inv = get_dataset(args.dataset, args.data_path, args.batch_real, args.subset, args=args)

    # print('\n================== Exp %d ==================\n '%exp)
    print('Hyper-parameters: \n', args.__dict__)

    save_dir = os.path.join(args.buffer_path, args.dataset)
    # if args.dataset == "ImageNet":
    #     save_dir = os.path.join(save_dir, args.subset, str(args.res))
    # if args.dataset in ["CIFAR10", "CIFAR100"] and not args.zca:
    #     save_dir += "_NO_ZCA"
    save_dir = os.path.join(save_dir, args.model)
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)


    ''' organize the real dataset '''
    images_all = []
    labels_all = []
    indices_class = [[] for c in range(num_classes)]
    print("BUILDING DATASET")
    for i in tqdm(range(len(dst_train))):
        sample = dst_train[i]
        images_all.append(torch.unsqueeze(sample[0], dim=0))
        labels_all.append(class_map[torch.tensor(sample[1]).item()])

    for i, lab in tqdm(enumerate(labels_all)):
        indices_class[lab].append(i)
    images_all = torch.cat(images_all, dim=0).to("cpu")
    labels_all = torch.tensor(labels_all, dtype=torch.long, device="cpu")

    for c in range(num_classes):
        print('class c = %d: %d real images'%(c, len(indices_class[c])))

    for ch in range(channel):
        print('real images channel %d, mean = %.4f, std = %.4f'%(ch, torch.mean(images_all[:, ch]), torch.std(images_all[:, ch])))

    criterion = nn.CrossEntropyLoss().to(args.device)

    trajectories = []

    dst_train = TensorDataset(copy.deepcopy(images_all.detach()), copy.deepcopy(labels_all.detach()))
    trainloader = torch.utils.data.DataLoader(dst_train, batch_size=args.batch_train, shuffle=True, num_workers=0)

    ''' set augmentation for whole-dataset training '''
    args.dc_aug_param = get_daparam(args.dataset, args.model, args.model, None)
    args.dc_aug_param['strategy'] = 'crop_scale_rotate'  # for whole-dataset training
    print('DC augmentation parameters: \n', args.dc_aug_param)

    for it in range(0, args.num_experts):

        ''' Train synthetic data '''
        teacher_net = get_network(args.model, channel, num_classes, im_size).to(args.device) # get a random model
        teacher_net.train()
        lr = args.lr_teacher


        base_optimizer = torch.optim.SGD(teacher_net.parameters(), lr=lr, momentum=args.mom, weight_decay=args.l2)
        # scheduler = CosineScheduler(T_max=args.train_epochs*len_dst_train, max_value=lr, min_value=0.0,
            # optimizer=base_optimizer)
        scheduler = torch.optim.lr_scheduler.StepLR(base_optimizer,step_size=args.train_epochs*len(trainloader),gamma=1)
        rho_scheduler = ProportionScheduler(pytorch_lr_scheduler=scheduler, max_lr=lr, min_lr=lr,
            max_value=args.rho_max, min_value=args.rho_min)
        teacher_optim = GSAM(params=teacher_net.parameters(), base_optimizer=base_optimizer,
            model=teacher_net, gsam_alpha=args.alpha, rho_scheduler=rho_scheduler, adaptive=args.adaptive)


        teacher_optim.zero_grad()

        timestamps = []

        timestamps.append([p.detach().cpu() for p in teacher_net.parameters()])

        lr_schedule = [args.train_epochs // 2 + 1]

        for e in range(args.train_epochs):

            train_loss, train_acc = epoch("train", dataloader=trainloader, net=teacher_net, optimizer=teacher_optim,
                                        criterion=criterion, args=args, aug=True, scheduler=scheduler)

            test_loss, test_acc = epoch("test", dataloader=testloader, net=teacher_net, optimizer=None,
                                        criterion=criterion, args=args, aug=False ,scheduler=scheduler)

            print("Itr: {}\tEpoch: {}\tTrain Acc: {}\tTest Acc: {}".format(it, e, train_acc, test_acc))

            timestamps.append([p.detach().cpu() for p in teacher_net.parameters()])

            # if e in lr_schedule and args.decay:
            #     lr *= 0.1
            #     teacher_optim = torch.optim.SGD(teacher_net.parameters(), lr=lr, momentum=args.mom, weight_decay=args.l2)
            #     teacher_optim.zero_grad()

        trajectories.append(timestamps)

        if len(trajectories) == args.save_interval:
            n = 0
            while os.path.exists(os.path.join(save_dir, "replay_buffer_{}.pt".format(n))):
                n += 1
            print("Saving {}".format(os.path.join(save_dir, "replay_buffer_{}.pt".format(n))))
            torch.save(trajectories, os.path.join(save_dir, "replay_buffer_{}.pt".format(n)))
            trajectories = []


class arguments():
    def __init__(self,):
        self.dataset = 'MNIST'
        self.subset = 'imagenette'
        self.model = 'ConvNet'
        self.num_experts = 100
        self.lr_teacher = 0.01
        self.batch_real = 256
        self.alpha = 0.4
        self.batch_train = 256
        self.rho_max = 2.0
        self.rho_min = 2.0
        self.dsa = 'False'
        self.dsa_strategy = 'color_crop_cutout_flip_scale_rotate'
        self.data_path = 'MNISTdata'
        self.buffer_path = './MNISTbuffers'
        self.adaptive = False
        self.train_epochs = 50
        self.zca = False
        self.decay = False
        self.mom = 0
        self.l2 = 0
        self.save_interval = 10

args = arguments()
main(args)
# Out:
# Hyper-parameters:
#  {'dataset': 'MNIST', 'subset': 'imagenette', 'model': 'ConvNet', 'num_experts': 100, 'lr_teacher': 0.01, 'batch_real': 256, 'alpha': 0.4, 'batch_train': 256, 'rho_max': 2.0, 'rho_min': 2.0, 'dsa': False, 'dsa_strategy': 'color_crop_cutout_flip_scale_rotate', 'data_path': 'MNISTdata', 'buffer_path': './MNISTbuffers', 'adaptive': True, 'train_epochs': 50, 'zca': False, 'decay': False, 'mom': 0, 'l2': 0, 'save_interval': 10, 'device': 'cuda', 'dsa_param': <utils.ParamDiffAug object at 0x7cf0e1ce5570>}
# BUILDING DATASET
# 100%|██████████| 60000/60000 [00:16<00:00, 3628.35it/s]
# 60000it [00:00, 2352891.72it/s]
# class c = 0: 5923 real images
# class c = 1: 6742 real images
# class c = 2: 5958 real images
# class c = 3: 6131 real images
# class c = 4: 5842 real images
# class c = 5: 5421 real images
# class c = 6: 5918 real images
# class c = 7: 6265 real images
# class c = 8: 5851 real images
# class c = 9: 5949 real images
# real images channel 0, mean = -0.0001, std = 1.0000
# DC augmentation parameters:
#  {'crop': 4, 'scale': 0.2, 'rotate': 45, 'noise': 0.001, 'strategy': 'crop_scale_rotate'}
# Itr: 0	Epoch: 0	Train Acc: 0.7118333333333333	Test Acc: 0.937
# Itr: 0	Epoch: 1	Train Acc: 0.8628833333333333	Test Acc: 0.9582
# Itr: 0	Epoch: 2	Train Acc: 0.8969333333333334	Test Acc: 0.9695
# Itr: 0	Epoch: 3	Train Acc: 0.9169833333333334	Test Acc: 0.9726
# Itr: 0	Epoch: 4	Train Acc: 0.9278166666666666	Test Acc: 0.977
# Itr: 0	Epoch: 5	Train Acc: 0.9357333333333333	Test Acc: 0.9794
# Itr: 0	Epoch: 6	Train Acc: 0.9422166666666667	Test Acc: 0.9819
# Itr: 0	Epoch: 7	Train Acc: 0.9470666666666666	Test Acc: 0.9829
# Itr: 0	Epoch: 8	Train Acc: 0.9512333333333334	Test Acc: 0.9851
# Itr: 0	Epoch: 9	Train Acc: 0.9544666666666667	Test Acc: 0.9836
# Itr: 0	Epoch: 10	Train Acc: 0.95715	Test Acc: 0.9854
# Itr: 0	Epoch: 11	Train Acc: 0.9612	Test Acc: 0.9865
# Itr: 0	Epoch: 12	Train Acc: 0.96115	Test Acc: 0.9864
# Itr: 0	Epoch: 13	Train Acc: 0.96285	Test Acc: 0.9882
# Itr: 0	Epoch: 14	Train Acc: 0.96485	Test Acc: 0.9874
# Itr: 0	Epoch: 15	Train Acc: 0.96705	Test Acc: 0.9882
# Itr: 0	Epoch: 16	Train Acc: 0.9679666666666666	Test Acc: 0.9882
# Itr: 0	Epoch: 17	Train Acc: 0.9694666666666667	Test Acc: 0.9894
# Itr: 0	Epoch: 18	Train Acc: 0.9702666666666667	Test Acc: 0.9891
# Itr: 0	Epoch: 19	Train Acc: 0.9708666666666667	Test Acc: 0.9895
# Itr: 0	Epoch: 20	Train Acc: 0.9717666666666667	Test Acc: 0.99
# Itr: 0	Epoch: 21	Train Acc: 0.97315	Test Acc: 0.9905
# Itr: 0	Epoch: 22	Train Acc: 0.9737166666666667	Test Acc: 0.9898
# Itr: 0	Epoch: 23	Train Acc: 0.9750833333333333	Test Acc: 0.9914
# Itr: 0	Epoch: 24	Train Acc: 0.9753166666666667	Test Acc: 0.9904
# Itr: 0	Epoch: 25	Train Acc: 0.9762333333333333	Test Acc: 0.991
# Itr: 0	Epoch: 26	Train Acc: 0.9761833333333333	Test Acc: 0.991
# Itr: 0	Epoch: 27	Train Acc: 0.9771	Test Acc: 0.9912
# Itr: 0	Epoch: 28	Train Acc: 0.9781833333333333	Test Acc: 0.9913
# Itr: 0	Epoch: 29	Train Acc: 0.9788333333333333	Test Acc: 0.9916
# Itr: 0	Epoch: 30	Train Acc: 0.9780666666666666	Test Acc: 0.9917
# Itr: 0	Epoch: 31	Train Acc: 0.97925	Test Acc: 0.9919
# Itr: 0	Epoch: 32	Train Acc: 0.9791	Test Acc: 0.9914
# Itr: 0	Epoch: 33	Train Acc: 0.9797666666666667	Test Acc: 0.9919
# Itr: 0	Epoch: 34	Train Acc: 0.9800166666666666	Test Acc: 0.9917
# Itr: 0	Epoch: 35	Train Acc: 0.9801666666666666	Test Acc: 0.9925
# Itr: 0	Epoch: 36	Train Acc: 0.98035	Test Acc: 0.992
# Itr: 0	Epoch: 37	Train Acc: 0.98155	Test Acc: 0.9926
# Itr: 0	Epoch: 38	Train Acc: 0.9812666666666666	Test Acc: 0.9927
# Itr: 0	Epoch: 39	Train Acc: 0.9816333333333334	Test Acc: 0.993
# Itr: 0	Epoch: 40	Train Acc: 0.9825833333333334	Test Acc: 0.9925
# Itr: 0	Epoch: 41	Train Acc: 0.9819	Test Acc: 0.9929
# Itr: 0	Epoch: 42	Train Acc: 0.9822166666666666	Test Acc: 0.9929
# Itr: 0	Epoch: 43	Train Acc: 0.9825333333333334	Test Acc: 0.993
# Itr: 0	Epoch: 44	Train Acc: 0.9820666666666666	Test Acc: 0.9923
# Itr: 0	Epoch: 45	Train Acc: 0.9832166666666666	Test Acc: 0.9933
# Itr: 0	Epoch: 46	Train Acc: 0.9833833333333334	Test Acc: 0.9928
# Itr: 0	Epoch: 47	Train Acc: 0.9833	Test Acc: 0.993
# Itr: 0	Epoch: 48	Train Acc: 0.9832666666666666	Test Acc: 0.9935
# Itr: 0	Epoch: 49	Train Acc: 0.98425	Test Acc: 0.9936
# Itr: 1	Epoch: 0	Train Acc: 0.7071166666666666	Test Acc: 0.9451
# Itr: 1	Epoch: 1	Train Acc: 0.8629666666666667	Test Acc: 0.9603
# Itr: 1	Epoch: 2	Train Acc: 0.89845	Test Acc: 0.9682
# Itr: 1	Epoch: 3	Train Acc: 0.91575	Test Acc: 0.9751
# Itr: 1	Epoch: 4	Train Acc: 0.9289333333333334	Test Acc: 0.9776
# Itr: 1	Epoch: 5	Train Acc: 0.9365	Test Acc: 0.9791
# Itr: 1	Epoch: 6	Train Acc: 0.94315	Test Acc: 0.9799
# Itr: 1	Epoch: 7	Train Acc: 0.9471666666666667	Test Acc: 0.9819
# Itr: 1	Epoch: 8	Train Acc: 0.9516666666666667	Test Acc: 0.9844
# Itr: 1	Epoch: 9	Train Acc: 0.9558	Test Acc: 0.9859
# Itr: 1	Epoch: 10	Train Acc: 0.95835	Test Acc: 0.9855
# Itr: 1	Epoch: 11	Train Acc: 0.9601666666666666	Test Acc: 0.9862
# Itr: 1	Epoch: 12	Train Acc: 0.9626166666666667	Test Acc: 0.9865
# Itr: 1	Epoch: 13	Train Acc: 0.96375	Test Acc: 0.9871
# Itr: 1	Epoch: 14	Train Acc: 0.9667333333333333	Test Acc: 0.9875
# Itr: 1	Epoch: 15	Train Acc: 0.96715	Test Acc: 0.988
# Itr: 1	Epoch: 16	Train Acc: 0.9692666666666667	Test Acc: 0.989
# Itr: 1	Epoch: 17	Train Acc: 0.9698333333333333	Test Acc: 0.9891
# Itr: 1	Epoch: 18	Train Acc: 0.97075	Test Acc: 0.9886
# Itr: 1	Epoch: 19	Train Acc: 0.972	Test Acc: 0.9895
# Itr: 1	Epoch: 20	Train Acc: 0.9720166666666666	Test Acc: 0.9889
# Itr: 1	Epoch: 21	Train Acc: 0.9730833333333333	Test Acc: 0.9897
# Itr: 1	Epoch: 22	Train Acc: 0.9741166666666666	Test Acc: 0.9894
# Itr: 1	Epoch: 23	Train Acc: 0.9751166666666666	Test Acc: 0.9892
# Itr: 1	Epoch: 24	Train Acc: 0.9759833333333333	Test Acc: 0.9904
# Itr: 1	Epoch: 25	Train Acc: 0.9762333333333333	Test Acc: 0.9904
# Itr: 1	Epoch: 26	Train Acc: 0.9764833333333334	Test Acc: 0.9906
# Itr: 1	Epoch: 27	Train Acc: 0.9772833333333333	Test Acc: 0.9899
# Itr: 1	Epoch: 28	Train Acc: 0.9768833333333333	Test Acc: 0.9907
# Itr: 1	Epoch: 29	Train Acc: 0.9776666666666667	Test Acc: 0.9911
# Itr: 1	Epoch: 30	Train Acc: 0.9788166666666667	Test Acc: 0.992
# Itr: 1	Epoch: 31	Train Acc: 0.9793333333333333	Test Acc: 0.9917
# Itr: 1	Epoch: 32	Train Acc: 0.9794	Test Acc: 0.9918
# Itr: 1	Epoch: 33	Train Acc: 0.97945	Test Acc: 0.991
# Itr: 1	Epoch: 34	Train Acc: 0.9807	Test Acc: 0.9923
# Itr: 1	Epoch: 35	Train Acc: 0.9807833333333333	Test Acc: 0.9913
# Itr: 1	Epoch: 36	Train Acc: 0.9807	Test Acc: 0.9923
# Itr: 1	Epoch: 37	Train Acc: 0.9814	Test Acc: 0.9922
# Itr: 1	Epoch: 38	Train Acc: 0.98135	Test Acc: 0.992
# Itr: 1	Epoch: 39	Train Acc: 0.98175	Test Acc: 0.9923
# Itr: 1	Epoch: 40	Train Acc: 0.9823333333333333	Test Acc: 0.9928
# Itr: 1	Epoch: 41	Train Acc: 0.9824	Test Acc: 0.9926
# Itr: 1	Epoch: 42	Train Acc: 0.98225	Test Acc: 0.993
# Itr: 1	Epoch: 43	Train Acc: 0.9834666666666667	Test Acc: 0.9924
# Itr: 1	Epoch: 44	Train Acc: 0.9828333333333333	Test Acc: 0.9929
# Itr: 1	Epoch: 45	Train Acc: 0.9829666666666667	Test Acc: 0.9925
# Itr: 1	Epoch: 46	Train Acc: 0.9831833333333333	Test Acc: 0.9934
# Itr: 1	Epoch: 47	Train Acc: 0.9831833333333333	Test Acc: 0.9925
# Itr: 1	Epoch: 48	Train Acc: 0.9832666666666666	Test Acc: 0.9929
# Itr: 1	Epoch: 49	Train Acc: 0.9833333333333333	Test Acc: 0.9928
# Itr: 2	Epoch: 0	Train Acc: 0.7097333333333333	Test Acc: 0.9415
# Itr: 2	Epoch: 1	Train Acc: 0.8653833333333333	Test Acc: 0.9623
# Itr: 2	Epoch: 2	Train Acc: 0.8995333333333333	Test Acc: 0.9706
# Itr: 2	Epoch: 3	Train Acc: 0.9181666666666667	Test Acc: 0.9759
# Itr: 2	Epoch: 4	Train Acc: 0.92855	Test Acc: 0.9773
# Itr: 2	Epoch: 5	Train Acc: 0.9364666666666667	Test Acc: 0.9802
# Itr: 2	Epoch: 6	Train Acc: 0.9445666666666667	Test Acc: 0.9819
# Itr: 2	Epoch: 7	Train Acc: 0.9495166666666667	Test Acc: 0.9826
# Itr: 2	Epoch: 8	Train Acc: 0.9505833333333333	Test Acc: 0.9835
# Itr: 2	Epoch: 9	Train Acc: 0.9548	Test Acc: 0.9845
# Itr: 2	Epoch: 10	Train Acc: 0.9577833333333333	Test Acc: 0.9855
# Itr: 2	Epoch: 11	Train Acc: 0.9601666666666666	Test Acc: 0.9851
# Itr: 2	Epoch: 12	Train Acc: 0.96335	Test Acc: 0.9866
# Itr: 2	Epoch: 13	Train Acc: 0.9648333333333333	Test Acc: 0.9871
# Itr: 2	Epoch: 14	Train Acc: 0.96665	Test Acc: 0.9884
# Itr: 2	Epoch: 15	Train Acc: 0.9674333333333334	Test Acc: 0.9879
# Itr: 2	Epoch: 16	Train Acc: 0.96905	Test Acc: 0.9893
# Itr: 2	Epoch: 17	Train Acc: 0.9700833333333333	Test Acc: 0.989
# Itr: 2	Epoch: 18	Train Acc: 0.9704	Test Acc: 0.9894
# Itr: 2	Epoch: 19	Train Acc: 0.97265	Test Acc: 0.9901
# Itr: 2	Epoch: 20	Train Acc: 0.9732666666666666	Test Acc: 0.9889
# Itr: 2	Epoch: 21	Train Acc: 0.9739666666666666	Test Acc: 0.991
# Itr: 2	Epoch: 22	Train Acc: 0.9744666666666667	Test Acc: 0.9901
# Itr: 2	Epoch: 23	Train Acc: 0.9754166666666667	Test Acc: 0.991
# Itr: 2	Epoch: 24	Train Acc: 0.9762333333333333	Test Acc: 0.9899
# Itr: 2	Epoch: 25	Train Acc: 0.9770166666666666	Test Acc: 0.9909
# Itr: 2	Epoch: 26	Train Acc: 0.9771	Test Acc: 0.9906
# Itr: 2	Epoch: 27	Train Acc: 0.9779666666666667	Test Acc: 0.991
# Itr: 2	Epoch: 28	Train Acc: 0.9781166666666666	Test Acc: 0.9916
# Itr: 2	Epoch: 29	Train Acc: 0.9784	Test Acc: 0.9915
# Itr: 2	Epoch: 30	Train Acc: 0.9788166666666667	Test Acc: 0.9916
# Itr: 2	Epoch: 31	Train Acc: 0.9798166666666667	Test Acc: 0.9923
# Itr: 2	Epoch: 32	Train Acc: 0.9803833333333334	Test Acc: 0.9925
# Itr: 2	Epoch: 33	Train Acc: 0.9807833333333333	Test Acc: 0.9925
# Itr: 2	Epoch: 34	Train Acc: 0.98105	Test Acc: 0.9926
# Itr: 2	Epoch: 35	Train Acc: 0.9810333333333333	Test Acc: 0.9926
# Itr: 2	Epoch: 36	Train Acc: 0.9813333333333333	Test Acc: 0.9923
# Itr: 2	Epoch: 37	Train Acc: 0.9822	Test Acc: 0.9927
# Itr: 2	Epoch: 38	Train Acc: 0.9819666666666667	Test Acc: 0.9929
# Itr: 2	Epoch: 39	Train Acc: 0.9824833333333334	Test Acc: 0.9928
# Itr: 2	Epoch: 40	Train Acc: 0.9836166666666667	Test Acc: 0.9932
# Itr: 2	Epoch: 41	Train Acc: 0.9834666666666667	Test Acc: 0.9926
# Itr: 2	Epoch: 42	Train Acc: 0.9827666666666667	Test Acc: 0.992
# Itr: 2	Epoch: 43	Train Acc: 0.9838333333333333	Test Acc: 0.9938
# Itr: 2	Epoch: 44	Train Acc: 0.9842333333333333	Test Acc: 0.9931
# Itr: 2	Epoch: 45	Train Acc: 0.9835666666666667	Test Acc: 0.9932
# Itr: 2	Epoch: 46	Train Acc: 0.9838333333333333	Test Acc: 0.9928
# Itr: 2	Epoch: 47	Train Acc: 0.9842833333333333	Test Acc: 0.9934
# Itr: 2	Epoch: 48	Train Acc: 0.9839333333333333	Test Acc: 0.9938
# Itr: 2	Epoch: 49	Train Acc: 0.9847833333333333	Test Acc: 0.9935
# Itr: 3	Epoch: 0	Train Acc: 0.7196	Test Acc: 0.9432
# Itr: 3	Epoch: 1	Train Acc: 0.86655	Test Acc: 0.9606
# Itr: 3	Epoch: 2	Train Acc: 0.8971	Test Acc: 0.9699
# Itr: 3	Epoch: 3	Train Acc: 0.91705	Test Acc: 0.9737
# Itr: 3	Epoch: 4	Train Acc: 0.9265	Test Acc: 0.9774
# Itr: 3	Epoch: 5	Train Acc: 0.93615	Test Acc: 0.9801
# Itr: 3	Epoch: 6	Train Acc: 0.9422666666666667	Test Acc: 0.9809
# Itr: 3	Epoch: 7	Train Acc: 0.9462166666666667	Test Acc: 0.9828
# Itr: 3	Epoch: 8	Train Acc: 0.9500333333333333	Test Acc: 0.9838
# Itr: 3	Epoch: 9	Train Acc: 0.9542166666666667	Test Acc: 0.9847
# Itr: 3	Epoch: 10	Train Acc: 0.9558166666666666	Test Acc: 0.9854
# Itr: 3	Epoch: 11	Train Acc: 0.9590833333333333	Test Acc: 0.9856
# Itr: 3	Epoch: 12	Train Acc: 0.9616333333333333	Test Acc: 0.985
# Itr: 3	Epoch: 13	Train Acc: 0.9638833333333333	Test Acc: 0.9876
# Itr: 3	Epoch: 14	Train Acc: 0.96455	Test Acc: 0.9881
# Itr: 3	Epoch: 15	Train Acc: 0.9663166666666667	Test Acc: 0.9885
# Itr: 3	Epoch: 16	Train Acc: 0.9678666666666667	Test Acc: 0.9887
# Itr: 3	Epoch: 17	Train Acc: 0.96975	Test Acc: 0.989
# Itr: 3	Epoch: 18	Train Acc: 0.9704	Test Acc: 0.9882
# Itr: 3	Epoch: 19	Train Acc: 0.9704666666666667	Test Acc: 0.9892
# Itr: 3	Epoch: 20	Train Acc: 0.9728	Test Acc: 0.989
# Itr: 3	Epoch: 21	Train Acc: 0.9740166666666666	Test Acc: 0.9892
# Itr: 3	Epoch: 22	Train Acc: 0.9740166666666666	Test Acc: 0.9902
# Itr: 3	Epoch: 23	Train Acc: 0.9743666666666667	Test Acc: 0.9898
# Itr: 3	Epoch: 24	Train Acc: 0.9754333333333334	Test Acc: 0.9914
# Itr: 3	Epoch: 25	Train Acc: 0.9752333333333333	Test Acc: 0.9904
# Itr: 3	Epoch: 26	Train Acc: 0.9756666666666667	Test Acc: 0.9911
# Itr: 3	Epoch: 27	Train Acc: 0.9774	Test Acc: 0.9908
# Itr: 3	Epoch: 28	Train Acc: 0.9766333333333334	Test Acc: 0.9909
# Itr: 3	Epoch: 29	Train Acc: 0.9776833333333333	Test Acc: 0.9907
# Itr: 3	Epoch: 30	Train Acc: 0.9787	Test Acc: 0.9913
# Itr: 3	Epoch: 31	Train Acc: 0.9789333333333333	Test Acc: 0.9918
# Itr: 3	Epoch: 32	Train Acc: 0.9789833333333333	Test Acc: 0.9915
# Itr: 3	Epoch: 33	Train Acc: 0.9809833333333333	Test Acc: 0.9919
# Itr: 3	Epoch: 34	Train Acc: 0.9794833333333334	Test Acc: 0.9922
# Itr: 3	Epoch: 35	Train Acc: 0.9810666666666666	Test Acc: 0.9918
# Itr: 3	Epoch: 36	Train Acc: 0.9811833333333333	Test Acc: 0.991
# Itr: 3	Epoch: 37	Train Acc: 0.9805	Test Acc: 0.9926
# Itr: 3	Epoch: 38	Train Acc: 0.981	Test Acc: 0.9923
# Itr: 3	Epoch: 39	Train Acc: 0.9813	Test Acc: 0.9928
# Itr: 3	Epoch: 40	Train Acc: 0.98165	Test Acc: 0.9925
# Itr: 3	Epoch: 41	Train Acc: 0.9819833333333333	Test Acc: 0.9928
# Itr: 3	Epoch: 42	Train Acc: 0.98245	Test Acc: 0.9921
# Itr: 3	Epoch: 43	Train Acc: 0.9829833333333333	Test Acc: 0.9924
# Itr: 3	Epoch: 44	Train Acc: 0.9826666666666667	Test Acc: 0.9934
# Itr: 3	Epoch: 45	Train Acc: 0.9830166666666666	Test Acc: 0.9931
# Itr: 3	Epoch: 46	Train Acc: 0.9830166666666666	Test Acc: 0.9932
# Itr: 3	Epoch: 47	Train Acc: 0.9841166666666666	Test Acc: 0.9935
# Itr: 3	Epoch: 48	Train Acc: 0.98355	Test Acc: 0.9921
# Itr: 3	Epoch: 49	Train Acc: 0.9841166666666666	Test Acc: 0.9937
# Itr: 4	Epoch: 0	Train Acc: 0.7180666666666666	Test Acc: 0.9402
# Itr: 4	Epoch: 1	Train Acc: 0.8662666666666666	Test Acc: 0.9596
# Itr: 4	Epoch: 2	Train Acc: 0.90025	Test Acc: 0.9682
# Itr: 4	Epoch: 3	Train Acc: 0.9172666666666667	Test Acc: 0.9733
# Itr: 4	Epoch: 4	Train Acc: 0.9296833333333333	Test Acc: 0.9782
# Itr: 4	Epoch: 5	Train Acc: 0.9373166666666667	Test Acc: 0.9804
# Itr: 4	Epoch: 6	Train Acc: 0.9448333333333333	Test Acc: 0.981
# Itr: 4	Epoch: 7	Train Acc: 0.94765	Test Acc: 0.9822
# Itr: 4	Epoch: 8	Train Acc: 0.9526166666666667	Test Acc: 0.984
# Itr: 4	Epoch: 9	Train Acc: 0.9558333333333333	Test Acc: 0.9842
# Itr: 4	Epoch: 10	Train Acc: 0.9578333333333333	Test Acc: 0.9858
# Itr: 4	Epoch: 11	Train Acc: 0.9607833333333333	Test Acc: 0.9861
# Itr: 4	Epoch: 12	Train Acc: 0.9624666666666667	Test Acc: 0.9875
# Itr: 4	Epoch: 13	Train Acc: 0.96385	Test Acc: 0.9871
# Itr: 4	Epoch: 14	Train Acc: 0.9656166666666667	Test Acc: 0.987
# Itr: 4	Epoch: 15	Train Acc: 0.9679333333333333	Test Acc: 0.9884
# Itr: 4	Epoch: 16	Train Acc: 0.9675	Test Acc: 0.9892
# Itr: 4	Epoch: 17	Train Acc: 0.9696333333333333	Test Acc: 0.9884
# Itr: 4	Epoch: 18	Train Acc: 0.9707333333333333	Test Acc: 0.9886
# Itr: 4	Epoch: 19	Train Acc: 0.9719166666666667	Test Acc: 0.9893
# Itr: 4	Epoch: 20	Train Acc: 0.9724166666666667	Test Acc: 0.9897
# Itr: 4	Epoch: 21	Train Acc: 0.97395	Test Acc: 0.9896
# Itr: 4	Epoch: 22	Train Acc: 0.9750166666666666	Test Acc: 0.9907
# Itr: 4	Epoch: 23	Train Acc: 0.9746333333333334	Test Acc: 0.9911
# Itr: 4	Epoch: 24	Train Acc: 0.9753	Test Acc: 0.9909
# Itr: 4	Epoch: 25	Train Acc: 0.9761666666666666	Test Acc: 0.9906
# Itr: 4	Epoch: 26	Train Acc: 0.9765833333333334	Test Acc: 0.9907
# Itr: 4	Epoch: 27	Train Acc: 0.9774833333333334	Test Acc: 0.9914
# Itr: 4	Epoch: 28	Train Acc: 0.9781166666666666	Test Acc: 0.991
# Itr: 4	Epoch: 29	Train Acc: 0.9782333333333333	Test Acc: 0.9915
# Itr: 4	Epoch: 30	Train Acc: 0.9785333333333334	Test Acc: 0.9913
# Itr: 4	Epoch: 31	Train Acc: 0.9793333333333333	Test Acc: 0.9919
# Itr: 4	Epoch: 32	Train Acc: 0.97885	Test Acc: 0.992
# Itr: 4	Epoch: 33	Train Acc: 0.9795	Test Acc: 0.9919
# Itr: 4	Epoch: 34	Train Acc: 0.9803833333333334	Test Acc: 0.9927
# Itr: 4	Epoch: 35	Train Acc: 0.9802833333333333	Test Acc: 0.992
# Itr: 4	Epoch: 36	Train Acc: 0.9813166666666666	Test Acc: 0.9911
# Itr: 4	Epoch: 37	Train Acc: 0.98155	Test Acc: 0.9917
# Itr: 4	Epoch: 38	Train Acc: 0.9812666666666666	Test Acc: 0.9923
# Itr: 4	Epoch: 39	Train Acc: 0.9819666666666667	Test Acc: 0.9925
# Itr: 4	Epoch: 40	Train Acc: 0.98235	Test Acc: 0.9924
# Itr: 4	Epoch: 41	Train Acc: 0.98265	Test Acc: 0.9929
# Itr: 4	Epoch: 42	Train Acc: 0.9831	Test Acc: 0.9927
# Itr: 4	Epoch: 43	Train Acc: 0.9831	Test Acc: 0.9934
# Itr: 4	Epoch: 44	Train Acc: 0.98395	Test Acc: 0.9934
# Itr: 4	Epoch: 45	Train Acc: 0.9838333333333333	Test Acc: 0.9932
# Itr: 4	Epoch: 46	Train Acc: 0.9831833333333333	Test Acc: 0.9935
# Itr: 4	Epoch: 47	Train Acc: 0.9838833333333333	Test Acc: 0.9934
# Itr: 4	Epoch: 48	Train Acc: 0.9831833333333333	Test Acc: 0.993
# Itr: 4	Epoch: 49	Train Acc: 0.98425	Test Acc: 0.9928
# Itr: 5	Epoch: 0	Train Acc: 0.7075833333333333	Test Acc: 0.9343
# Itr: 5	Epoch: 1	Train Acc: 0.8631333333333333	Test Acc: 0.9591
# Itr: 5	Epoch: 2	Train Acc: 0.8972166666666667	Test Acc: 0.9676
# Itr: 5	Epoch: 3	Train Acc: 0.9146833333333333	Test Acc: 0.9722
# Itr: 5	Epoch: 4	Train Acc: 0.92435	Test Acc: 0.9769
# Itr: 5	Epoch: 5	Train Acc: 0.9359833333333333	Test Acc: 0.9795
# Itr: 5	Epoch: 6	Train Acc: 0.9396166666666667	Test Acc: 0.9815
# Itr: 5	Epoch: 7	Train Acc: 0.9457833333333333	Test Acc: 0.9822
# Itr: 5	Epoch: 8	Train Acc: 0.9501333333333334	Test Acc: 0.9833
# Itr: 5	Epoch: 9	Train Acc: 0.95375	Test Acc: 0.9838
# Itr: 5	Epoch: 10	Train Acc: 0.9561166666666666	Test Acc: 0.9841
# Itr: 5	Epoch: 11	Train Acc: 0.9592833333333334	Test Acc: 0.9854
# Itr: 5	Epoch: 12	Train Acc: 0.9611833333333333	Test Acc: 0.9857
# Itr: 5	Epoch: 13	Train Acc: 0.9628	Test Acc: 0.9858
# Itr: 5	Epoch: 14	Train Acc: 0.96385	Test Acc: 0.9881
# Itr: 5	Epoch: 15	Train Acc: 0.9661333333333333	Test Acc: 0.9879
# Itr: 5	Epoch: 16	Train Acc: 0.96685	Test Acc: 0.9887
# Itr: 5	Epoch: 17	Train Acc: 0.9685833333333334	Test Acc: 0.9883
# Itr: 5	Epoch: 18	Train Acc: 0.9698833333333333	Test Acc: 0.9889
# Itr: 5	Epoch: 19	Train Acc: 0.97095	Test Acc: 0.9893
# Itr: 5	Epoch: 20	Train Acc: 0.9716833333333333	Test Acc: 0.9897
# Itr: 5	Epoch: 21	Train Acc: 0.9718833333333333	Test Acc: 0.9897
# Itr: 5	Epoch: 22	Train Acc: 0.9729833333333333	Test Acc: 0.9898
# Itr: 5	Epoch: 23	Train Acc: 0.97325	Test Acc: 0.9903
# Itr: 5	Epoch: 24	Train Acc: 0.9737333333333333	Test Acc: 0.9909
# Itr: 5	Epoch: 25	Train Acc: 0.9750166666666666	Test Acc: 0.9908
# Itr: 5	Epoch: 26	Train Acc: 0.9742333333333333	Test Acc: 0.9904
# Itr: 5	Epoch: 27	Train Acc: 0.97715	Test Acc: 0.9905
# Itr: 5	Epoch: 28	Train Acc: 0.9764166666666667	Test Acc: 0.9913
# Itr: 5	Epoch: 29	Train Acc: 0.9772166666666666	Test Acc: 0.9912
# Itr: 5	Epoch: 30	Train Acc: 0.9774166666666667	Test Acc: 0.9912
# Itr: 5	Epoch: 31	Train Acc: 0.9783	Test Acc: 0.9919
# Itr: 5	Epoch: 32	Train Acc: 0.9786833333333333	Test Acc: 0.9915
# Itr: 5	Epoch: 33	Train Acc: 0.9791666666666666	Test Acc: 0.9921
# Itr: 5	Epoch: 34	Train Acc: 0.97935	Test Acc: 0.9918
# Itr: 5	Epoch: 35	Train Acc: 0.9796666666666667	Test Acc: 0.9924
# Itr: 5	Epoch: 36	Train Acc: 0.9806833333333334	Test Acc: 0.9923
# Itr: 5	Epoch: 37	Train Acc: 0.9804333333333334	Test Acc: 0.9922
# Itr: 5	Epoch: 38	Train Acc: 0.9815833333333334	Test Acc: 0.9924
# Itr: 5	Epoch: 39	Train Acc: 0.9809166666666667	Test Acc: 0.9922
# Itr: 5	Epoch: 40	Train Acc: 0.9819	Test Acc: 0.9922
# Itr: 5	Epoch: 41	Train Acc: 0.98155	Test Acc: 0.9926
# Itr: 5	Epoch: 42	Train Acc: 0.9814333333333334	Test Acc: 0.9925
# Itr: 5	Epoch: 43	Train Acc: 0.98215	Test Acc: 0.9918
# Itr: 5	Epoch: 44	Train Acc: 0.98285	Test Acc: 0.9929
# Itr: 5	Epoch: 45	Train Acc: 0.98285	Test Acc: 0.9931
# Itr: 5	Epoch: 46	Train Acc: 0.9833666666666666	Test Acc: 0.9929
# Itr: 5	Epoch: 47	Train Acc: 0.9838333333333333	Test Acc: 0.9937
# Itr: 5	Epoch: 48	Train Acc: 0.9838166666666667	Test Acc: 0.9935
# Itr: 5	Epoch: 49	Train Acc: 0.9833666666666666	Test Acc: 0.9929
# Itr: 6	Epoch: 0	Train Acc: 0.7123666666666667	Test Acc: 0.9423
# Itr: 6	Epoch: 1	Train Acc: 0.8641	Test Acc: 0.9627
# Itr: 6	Epoch: 2	Train Acc: 0.8978166666666667	Test Acc: 0.9686
# Itr: 6	Epoch: 3	Train Acc: 0.91665	Test Acc: 0.9724
# Itr: 6	Epoch: 4	Train Acc: 0.9288166666666666	Test Acc: 0.9787
# Itr: 6	Epoch: 5	Train Acc: 0.9354666666666667	Test Acc: 0.9773
# Itr: 6	Epoch: 6	Train Acc: 0.94175	Test Acc: 0.9812
# Itr: 6	Epoch: 7	Train Acc: 0.94685	Test Acc: 0.9822
# Itr: 6	Epoch: 8	Train Acc: 0.9526	Test Acc: 0.9825
# Itr: 6	Epoch: 9	Train Acc: 0.95425	Test Acc: 0.9835
# Itr: 6	Epoch: 10	Train Acc: 0.9569833333333333	Test Acc: 0.985
# Itr: 6	Epoch: 11	Train Acc: 0.9596666666666667	Test Acc: 0.9854
# Itr: 6	Epoch: 12	Train Acc: 0.9613	Test Acc: 0.987
# Itr: 6	Epoch: 13	Train Acc: 0.9630833333333333	Test Acc: 0.9865
# Itr: 6	Epoch: 14	Train Acc: 0.96565	Test Acc: 0.9876
# Itr: 6	Epoch: 15	Train Acc: 0.9662666666666667	Test Acc: 0.9883
# Itr: 6	Epoch: 16	Train Acc: 0.96785	Test Acc: 0.9877
# Itr: 6	Epoch: 17	Train Acc: 0.9680333333333333	Test Acc: 0.9876
# Itr: 6	Epoch: 18	Train Acc: 0.9702833333333334	Test Acc: 0.9895
# Itr: 6	Epoch: 19	Train Acc: 0.9713	Test Acc: 0.9887
# Itr: 6	Epoch: 20	Train Acc: 0.9714	Test Acc: 0.9888
# Itr: 6	Epoch: 21	Train Acc: 0.9729166666666667	Test Acc: 0.9899
# Itr: 6	Epoch: 22	Train Acc: 0.9730333333333333	Test Acc: 0.9897
# Itr: 6	Epoch: 23	Train Acc: 0.9748	Test Acc: 0.9896
# Itr: 6	Epoch: 24	Train Acc: 0.9745	Test Acc: 0.99
# Itr: 6	Epoch: 25	Train Acc: 0.97495	Test Acc: 0.9912
# Itr: 6	Epoch: 26	Train Acc: 0.9754166666666667	Test Acc: 0.9907
# Itr: 6	Epoch: 27	Train Acc: 0.9765166666666667	Test Acc: 0.9906
# Itr: 6	Epoch: 28	Train Acc: 0.9773333333333334	Test Acc: 0.9909
# Itr: 6	Epoch: 29	Train Acc: 0.9774833333333334	Test Acc: 0.9907
# Itr: 6	Epoch: 30	Train Acc: 0.9778833333333333	Test Acc: 0.9911
# Itr: 6	Epoch: 31	Train Acc: 0.97875	Test Acc: 0.9912
# Itr: 6	Epoch: 32	Train Acc: 0.9783666666666667	Test Acc: 0.9916
# Itr: 6	Epoch: 33	Train Acc: 0.97965	Test Acc: 0.9912
# Itr: 6	Epoch: 34	Train Acc: 0.9795	Test Acc: 0.9917
# Itr: 6	Epoch: 35	Train Acc: 0.9805333333333334	Test Acc: 0.992
# Itr: 6	Epoch: 36	Train Acc: 0.9802166666666666	Test Acc: 0.9914
# Itr: 6	Epoch: 37	Train Acc: 0.9810833333333333	Test Acc: 0.9923
# Itr: 6	Epoch: 38	Train Acc: 0.9808333333333333	Test Acc: 0.9924
# Itr: 6	Epoch: 39	Train Acc: 0.9809333333333333	Test Acc: 0.9922
# Itr: 6	Epoch: 40	Train Acc: 0.9815166666666667	Test Acc: 0.9925
# Itr: 6	Epoch: 41	Train Acc: 0.9820666666666666	Test Acc: 0.9928
# Itr: 6	Epoch: 42	Train Acc: 0.9823333333333333	Test Acc: 0.9932
# Itr: 6	Epoch: 43	Train Acc: 0.9826666666666667	Test Acc: 0.9931
# Itr: 6	Epoch: 44	Train Acc: 0.9822833333333333	Test Acc: 0.9925
# Itr: 6	Epoch: 45	Train Acc: 0.9826	Test Acc: 0.9928
# Itr: 6	Epoch: 46	Train Acc: 0.9831166666666666	Test Acc: 0.9934
# Itr: 6	Epoch: 47	Train Acc: 0.98285	Test Acc: 0.9933
# Itr: 6	Epoch: 48	Train Acc: 0.9836666666666667	Test Acc: 0.9937
# Itr: 6	Epoch: 49	Train Acc: 0.9831666666666666	Test Acc: 0.9928
# Itr: 7	Epoch: 0	Train Acc: 0.7212666666666666	Test Acc: 0.942
# Itr: 7	Epoch: 1	Train Acc: 0.8660333333333333	Test Acc: 0.9626
# Itr: 7	Epoch: 2	Train Acc: 0.90035	Test Acc: 0.9665
# Itr: 7	Epoch: 3	Train Acc: 0.9183	Test Acc: 0.9754
# Itr: 7	Epoch: 4	Train Acc: 0.9307166666666666	Test Acc: 0.9777
# Itr: 7	Epoch: 5	Train Acc: 0.9368666666666666	Test Acc: 0.9797
# Itr: 7	Epoch: 6	Train Acc: 0.9437333333333333	Test Acc: 0.9814
# Itr: 7	Epoch: 7	Train Acc: 0.9487666666666666	Test Acc: 0.9822
# Itr: 7	Epoch: 8	Train Acc: 0.95185	Test Acc: 0.9842
# Itr: 7	Epoch: 9	Train Acc: 0.9556	Test Acc: 0.9843
# Itr: 7	Epoch: 10	Train Acc: 0.9601166666666666	Test Acc: 0.9859
# Itr: 7	Epoch: 11	Train Acc: 0.9605666666666667	Test Acc: 0.9849
# Itr: 7	Epoch: 12	Train Acc: 0.96365	Test Acc: 0.9863
# Itr: 7	Epoch: 13	Train Acc: 0.96515	Test Acc: 0.987
# Itr: 7	Epoch: 14	Train Acc: 0.9661666666666666	Test Acc: 0.9882
# Itr: 7	Epoch: 15	Train Acc: 0.9686666666666667	Test Acc: 0.9873
# Itr: 7	Epoch: 16	Train Acc: 0.96825	Test Acc: 0.9889
# Itr: 7	Epoch: 17	Train Acc: 0.9699666666666666	Test Acc: 0.9895
# Itr: 7	Epoch: 18	Train Acc: 0.9723666666666667	Test Acc: 0.9886
# Itr: 7	Epoch: 19	Train Acc: 0.9721	Test Acc: 0.9897
# Itr: 7	Epoch: 20	Train Acc: 0.9724166666666667	Test Acc: 0.991
# Itr: 7	Epoch: 21	Train Acc: 0.9743833333333334	Test Acc: 0.9903
# Itr: 7	Epoch: 22	Train Acc: 0.9749166666666667	Test Acc: 0.9905
# Itr: 7	Epoch: 23	Train Acc: 0.9752333333333333	Test Acc: 0.9903
# Itr: 7	Epoch: 24	Train Acc: 0.9763	Test Acc: 0.9915
# Itr: 7	Epoch: 25	Train Acc: 0.9768666666666667	Test Acc: 0.9911
# Itr: 7	Epoch: 26	Train Acc: 0.9776	Test Acc: 0.9912
# Itr: 7	Epoch: 27	Train Acc: 0.97795	Test Acc: 0.9909
# Itr: 7	Epoch: 28	Train Acc: 0.9783666666666667	Test Acc: 0.992
# Itr: 7	Epoch: 29	Train Acc: 0.9783666666666667	Test Acc: 0.9919
# Itr: 7	Epoch: 30	Train Acc: 0.9793166666666666	Test Acc: 0.9922
# Itr: 7	Epoch: 31	Train Acc: 0.97985	Test Acc: 0.9926
# Itr: 7	Epoch: 32	Train Acc: 0.97885	Test Acc: 0.992
# Itr: 7	Epoch: 33	Train Acc: 0.9809166666666667	Test Acc: 0.9928
# Itr: 7	Epoch: 34	Train Acc: 0.9805166666666667	Test Acc: 0.9926
# Itr: 7	Epoch: 35	Train Acc: 0.9808	Test Acc: 0.9927
# Itr: 7	Epoch: 36	Train Acc: 0.9814166666666667	Test Acc: 0.9925
# Itr: 7	Epoch: 37	Train Acc: 0.9813666666666667	Test Acc: 0.9926
# Itr: 7	Epoch: 38	Train Acc: 0.98175	Test Acc: 0.9935
# Itr: 7	Epoch: 39	Train Acc: 0.9825166666666667	Test Acc: 0.9919
# Itr: 7	Epoch: 40	Train Acc: 0.9825166666666667	Test Acc: 0.9933
# Itr: 7	Epoch: 41	Train Acc: 0.9830833333333333	Test Acc: 0.9931
# Itr: 7	Epoch: 42	Train Acc: 0.98235	Test Acc: 0.993
# Itr: 7	Epoch: 43	Train Acc: 0.9828833333333333	Test Acc: 0.993
# Itr: 7	Epoch: 44	Train Acc: 0.9838333333333333	Test Acc: 0.9931
# Itr: 7	Epoch: 45	Train Acc: 0.9837166666666667	Test Acc: 0.9935
# Itr: 7	Epoch: 46	Train Acc: 0.9838666666666667	Test Acc: 0.994
# Itr: 7	Epoch: 47	Train Acc: 0.9840166666666667	Test Acc: 0.9928
# Itr: 7	Epoch: 48	Train Acc: 0.9843666666666666	Test Acc: 0.9933
# Itr: 7	Epoch: 49	Train Acc: 0.9846333333333334	Test Acc: 0.9933
# Itr: 8	Epoch: 0	Train Acc: 0.7134166666666667	Test Acc: 0.9392
# Itr: 8	Epoch: 1	Train Acc: 0.8619166666666667	Test Acc: 0.9589
# Itr: 8	Epoch: 2	Train Acc: 0.89855	Test Acc: 0.9676
# Itr: 8	Epoch: 3	Train Acc: 0.9155333333333333	Test Acc: 0.9742
# Itr: 8	Epoch: 4	Train Acc: 0.9284	Test Acc: 0.9783
# Itr: 8	Epoch: 5	Train Acc: 0.9350666666666667	Test Acc: 0.9797
# Itr: 8	Epoch: 6	Train Acc: 0.94255	Test Acc: 0.9806
# Itr: 8	Epoch: 7	Train Acc: 0.9452166666666667	Test Acc: 0.9805
# Itr: 8	Epoch: 8	Train Acc: 0.949	Test Acc: 0.984
# Itr: 8	Epoch: 9	Train Acc: 0.9535	Test Acc: 0.984
# Itr: 8	Epoch: 10	Train Acc: 0.95715	Test Acc: 0.9844
# Itr: 8	Epoch: 11	Train Acc: 0.9574666666666667	Test Acc: 0.9859
# Itr: 8	Epoch: 12	Train Acc: 0.9600166666666666	Test Acc: 0.9856
# Itr: 8	Epoch: 13	Train Acc: 0.9626333333333333	Test Acc: 0.9867
# Itr: 8	Epoch: 14	Train Acc: 0.9644	Test Acc: 0.9864
# Itr: 8	Epoch: 15	Train Acc: 0.9657	Test Acc: 0.9877
# Itr: 8	Epoch: 16	Train Acc: 0.96685	Test Acc: 0.9879
# Itr: 8	Epoch: 17	Train Acc: 0.9680666666666666	Test Acc: 0.9883
# Itr: 8	Epoch: 18	Train Acc: 0.9683666666666667	Test Acc: 0.9892
# Itr: 8	Epoch: 19	Train Acc: 0.9700833333333333	Test Acc: 0.9898
# Itr: 8	Epoch: 20	Train Acc: 0.9708333333333333	Test Acc: 0.9888
# Itr: 8	Epoch: 21	Train Acc: 0.97265	Test Acc: 0.9875
# Itr: 8	Epoch: 22	Train Acc: 0.9736333333333334	Test Acc: 0.9893
# Itr: 8	Epoch: 23	Train Acc: 0.9733333333333334	Test Acc: 0.99
# Itr: 8	Epoch: 24	Train Acc: 0.9742833333333333	Test Acc: 0.9894
# Itr: 8	Epoch: 25	Train Acc: 0.97535	Test Acc: 0.991
# Itr: 8	Epoch: 26	Train Acc: 0.9755	Test Acc: 0.9904
# Itr: 8	Epoch: 27	Train Acc: 0.9759833333333333	Test Acc: 0.9899
# Itr: 8	Epoch: 28	Train Acc: 0.97655	Test Acc: 0.9909
# Itr: 8	Epoch: 29	Train Acc: 0.9762333333333333	Test Acc: 0.9912
# Itr: 8	Epoch: 30	Train Acc: 0.9783	Test Acc: 0.991
# Itr: 8	Epoch: 31	Train Acc: 0.9782833333333333	Test Acc: 0.9918
# Itr: 8	Epoch: 32	Train Acc: 0.97875	Test Acc: 0.9916
# Itr: 8	Epoch: 33	Train Acc: 0.9799333333333333	Test Acc: 0.9912
# Itr: 8	Epoch: 34	Train Acc: 0.9796833333333334	Test Acc: 0.9918
# Itr: 8	Epoch: 35	Train Acc: 0.9786833333333333	Test Acc: 0.9917
# Itr: 8	Epoch: 36	Train Acc: 0.9796	Test Acc: 0.9914
# Itr: 8	Epoch: 37	Train Acc: 0.9805666666666667	Test Acc: 0.9917
# Itr: 8	Epoch: 38	Train Acc: 0.9804	Test Acc: 0.992
# Itr: 8	Epoch: 39	Train Acc: 0.98135	Test Acc: 0.9918
# Itr: 8	Epoch: 40	Train Acc: 0.9806333333333334	Test Acc: 0.9915
# Itr: 8	Epoch: 41	Train Acc: 0.9820666666666666	Test Acc: 0.9923
# Itr: 8	Epoch: 42	Train Acc: 0.9813333333333333	Test Acc: 0.9924
# Itr: 8	Epoch: 43	Train Acc: 0.9816666666666667	Test Acc: 0.992
# Itr: 8	Epoch: 44	Train Acc: 0.9818166666666667	Test Acc: 0.9928
# Itr: 8	Epoch: 45	Train Acc: 0.9831	Test Acc: 0.9927
# Itr: 8	Epoch: 46	Train Acc: 0.9830166666666666	Test Acc: 0.9924
# Itr: 8	Epoch: 47	Train Acc: 0.9832333333333333	Test Acc: 0.9924
# Itr: 8	Epoch: 48	Train Acc: 0.9835666666666667	Test Acc: 0.9924
# Itr: 8	Epoch: 49	Train Acc: 0.9837333333333333	Test Acc: 0.9925
# Itr: 9	Epoch: 0	Train Acc: 0.7095666666666667	Test Acc: 0.9413
# Itr: 9	Epoch: 1	Train Acc: 0.8617	Test Acc: 0.9596
# Itr: 9	Epoch: 2	Train Acc: 0.8998666666666667	Test Acc: 0.9689
# Itr: 9	Epoch: 3	Train Acc: 0.9142833333333333	Test Acc: 0.9733
# Itr: 9	Epoch: 4	Train Acc: 0.9291666666666667	Test Acc: 0.9768
# Itr: 9	Epoch: 5	Train Acc: 0.93715	Test Acc: 0.98
# Itr: 9	Epoch: 6	Train Acc: 0.9432333333333334	Test Acc: 0.9812
# Itr: 9	Epoch: 7	Train Acc: 0.9468666666666666	Test Acc: 0.983
# Itr: 9	Epoch: 8	Train Acc: 0.9512	Test Acc: 0.9838
# Itr: 9	Epoch: 9	Train Acc: 0.9553666666666667	Test Acc: 0.9854
# Itr: 9	Epoch: 10	Train Acc: 0.9572	Test Acc: 0.9857
# Itr: 9	Epoch: 11	Train Acc: 0.9600333333333333	Test Acc: 0.9861
# Itr: 9	Epoch: 12	Train Acc: 0.9617666666666667	Test Acc: 0.9868
# Itr: 9	Epoch: 13	Train Acc: 0.9637	Test Acc: 0.9868
# Itr: 9	Epoch: 14	Train Acc: 0.96565	Test Acc: 0.9877
# Itr: 9	Epoch: 15	Train Acc: 0.9664	Test Acc: 0.9886
# Itr: 9	Epoch: 16	Train Acc: 0.9681833333333333	Test Acc: 0.9888
# Itr: 9	Epoch: 17	Train Acc: 0.9689666666666666	Test Acc: 0.9884
# Itr: 9	Epoch: 18	Train Acc: 0.9693833333333334	Test Acc: 0.9891
# Itr: 9	Epoch: 19	Train Acc: 0.9712833333333334	Test Acc: 0.9893
# Itr: 9	Epoch: 20	Train Acc: 0.9722333333333333	Test Acc: 0.9894
# Itr: 9	Epoch: 21	Train Acc: 0.9716666666666667	Test Acc: 0.9899
# Itr: 9	Epoch: 22	Train Acc: 0.97315	Test Acc: 0.99
# Itr: 9	Epoch: 23	Train Acc: 0.9755333333333334	Test Acc: 0.9896
# Itr: 9	Epoch: 24	Train Acc: 0.9750666666666666	Test Acc: 0.99
# Itr: 9	Epoch: 25	Train Acc: 0.9757666666666667	Test Acc: 0.9901
# Itr: 9	Epoch: 26	Train Acc: 0.9764666666666667	Test Acc: 0.9907
# Itr: 9	Epoch: 27	Train Acc: 0.9770666666666666	Test Acc: 0.9911
# Itr: 9	Epoch: 28	Train Acc: 0.9777833333333333	Test Acc: 0.9909
# Itr: 9	Epoch: 29	Train Acc: 0.9776333333333334	Test Acc: 0.991
# Itr: 9	Epoch: 30	Train Acc: 0.9785333333333334	Test Acc: 0.9914
# Itr: 9	Epoch: 31	Train Acc: 0.9782333333333333	Test Acc: 0.9911
# Itr: 9	Epoch: 32	Train Acc: 0.9788666666666667	Test Acc: 0.9911
# Itr: 9	Epoch: 33	Train Acc: 0.9801166666666666	Test Acc: 0.9922
# Itr: 9	Epoch: 34	Train Acc: 0.9794333333333334	Test Acc: 0.9914
# Itr: 9	Epoch: 35	Train Acc: 0.9798666666666667	Test Acc: 0.9924
# Itr: 9	Epoch: 36	Train Acc: 0.9803333333333333	Test Acc: 0.9913
# Itr: 9	Epoch: 37	Train Acc: 0.9815166666666667	Test Acc: 0.9923
# Itr: 9	Epoch: 38	Train Acc: 0.9813333333333333	Test Acc: 0.9921
# Itr: 9	Epoch: 39	Train Acc: 0.9817833333333333	Test Acc: 0.9928
# Itr: 9	Epoch: 40	Train Acc: 0.9816333333333334	Test Acc: 0.9925
# Itr: 9	Epoch: 41	Train Acc: 0.98205	Test Acc: 0.9924
# Itr: 9	Epoch: 42	Train Acc: 0.9823166666666666	Test Acc: 0.9924
# Itr: 9	Epoch: 43	Train Acc: 0.9830833333333333	Test Acc: 0.9928
# Itr: 9	Epoch: 44	Train Acc: 0.9822333333333333	Test Acc: 0.9925
# Itr: 9	Epoch: 45	Train Acc: 0.9829	Test Acc: 0.9924
# Itr: 9	Epoch: 46	Train Acc: 0.9833333333333333	Test Acc: 0.9926
# Itr: 9	Epoch: 47	Train Acc: 0.9828833333333333	Test Acc: 0.9927
# Itr: 9	Epoch: 48	Train Acc: 0.9840833333333333	Test Acc: 0.9931
# Itr: 9	Epoch: 49	Train Acc: 0.9835166666666667	Test Acc: 0.9929
# Saving ./MNISTbuffers/MNIST/ConvNet/replay_buffer_0.pt
# Itr: 10	Epoch: 0	Train Acc: 0.7125166666666667	Test Acc: 0.9294
# Itr: 10	Epoch: 1	Train Acc: 0.8618833333333333	Test Acc: 0.9592
# Itr: 10	Epoch: 2	Train Acc: 0.89675	Test Acc: 0.9698
# Itr: 10	Epoch: 3	Train Acc: 0.9156333333333333	Test Acc: 0.972
# Itr: 10	Epoch: 4	Train Acc: 0.9261666666666667	Test Acc: 0.9779
# Itr: 10	Epoch: 5	Train Acc: 0.93465	Test Acc: 0.9781
# Itr: 10	Epoch: 6	Train Acc: 0.94185	Test Acc: 0.9796
# Itr: 10	Epoch: 7	Train Acc: 0.9445666666666667	Test Acc: 0.9801
# Itr: 10	Epoch: 8	Train Acc: 0.9502333333333334	Test Acc: 0.984
# Itr: 10	Epoch: 9	Train Acc: 0.95295	Test Acc: 0.9839
# Itr: 10	Epoch: 10	Train Acc: 0.9549166666666666	Test Acc: 0.9841
# Itr: 10	Epoch: 11	Train Acc: 0.9585166666666667	Test Acc: 0.9856
# Itr: 10	Epoch: 12	Train Acc: 0.9607166666666667	Test Acc: 0.9855
# Itr: 10	Epoch: 13	Train Acc: 0.9621833333333333	Test Acc: 0.9847
# Itr: 10	Epoch: 14	Train Acc: 0.9632	Test Acc: 0.9872
# Itr: 10	Epoch: 15	Train Acc: 0.9649166666666666	Test Acc: 0.9876
# Itr: 10	Epoch: 16	Train Acc: 0.9667166666666667	Test Acc: 0.9886
# Itr: 10	Epoch: 17	Train Acc: 0.9685	Test Acc: 0.9888
# Itr: 10	Epoch: 18	Train Acc: 0.9693166666666667	Test Acc: 0.9883
# Itr: 10	Epoch: 19	Train Acc: 0.97015	Test Acc: 0.9895
# Itr: 10	Epoch: 20	Train Acc: 0.9708666666666667	Test Acc: 0.9893
# Itr: 10	Epoch: 21	Train Acc: 0.9725666666666667	Test Acc: 0.9891
# Itr: 10	Epoch: 22	Train Acc: 0.9721166666666666	Test Acc: 0.9895
# Itr: 10	Epoch: 23	Train Acc: 0.9734	Test Acc: 0.9899
# Itr: 10	Epoch: 24	Train Acc: 0.9743833333333334	Test Acc: 0.9902
# Itr: 10	Epoch: 25	Train Acc: 0.9755666666666667	Test Acc: 0.9908
# Itr: 10	Epoch: 26	Train Acc: 0.9756	Test Acc: 0.9909
# Itr: 10	Epoch: 27	Train Acc: 0.9762833333333333	Test Acc: 0.9907
# Itr: 10	Epoch: 28	Train Acc: 0.9759666666666666	Test Acc: 0.9909
# Itr: 10	Epoch: 29	Train Acc: 0.9770833333333333	Test Acc: 0.9908
# Itr: 10	Epoch: 30	Train Acc: 0.9782	Test Acc: 0.9918
# Itr: 10	Epoch: 31	Train Acc: 0.9787666666666667	Test Acc: 0.9912
# Itr: 10	Epoch: 32	Train Acc: 0.9783666666666667	Test Acc: 0.9914
# Itr: 10	Epoch: 33	Train Acc: 0.9789666666666667	Test Acc: 0.9916
# Itr: 10	Epoch: 34	Train Acc: 0.9795	Test Acc: 0.9917
# Itr: 10	Epoch: 35	Train Acc: 0.9796	Test Acc: 0.9912
# Itr: 10	Epoch: 36	Train Acc: 0.9793833333333334	Test Acc: 0.9917
# Itr: 10	Epoch: 37	Train Acc: 0.9808666666666667	Test Acc: 0.9924
# Itr: 10	Epoch: 38	Train Acc: 0.9809333333333333	Test Acc: 0.9921
# Itr: 10	Epoch: 39	Train Acc: 0.9817	Test Acc: 0.9925
# Itr: 10	Epoch: 40	Train Acc: 0.9812166666666666	Test Acc: 0.992
# Itr: 10	Epoch: 41	Train Acc: 0.9818166666666667	Test Acc: 0.9927
# Itr: 10	Epoch: 42	Train Acc: 0.9828	Test Acc: 0.9921
# Itr: 10	Epoch: 43	Train Acc: 0.98225	Test Acc: 0.9929
# Itr: 10	Epoch: 44	Train Acc: 0.9822333333333333	Test Acc: 0.9932
# Itr: 10	Epoch: 45	Train Acc: 0.9835833333333334	Test Acc: 0.9928
# Itr: 10	Epoch: 46	Train Acc: 0.9830333333333333	Test Acc: 0.9929
# Itr: 10	Epoch: 47	Train Acc: 0.9831	Test Acc: 0.993
# Itr: 10	Epoch: 48	Train Acc: 0.9836333333333334	Test Acc: 0.9927
# Itr: 10	Epoch: 49	Train Acc: 0.9836666666666667	Test Acc: 0.9929
# Itr: 11	Epoch: 0	Train Acc: 0.7052166666666667	Test Acc: 0.9392
# Itr: 11	Epoch: 1	Train Acc: 0.8642333333333333	Test Acc: 0.9589
# Itr: 11	Epoch: 2	Train Acc: 0.8992	Test Acc: 0.9667
# Itr: 11	Epoch: 3	Train Acc: 0.91785	Test Acc: 0.9746
# Itr: 11	Epoch: 4	Train Acc: 0.9278833333333333	Test Acc: 0.9744
# Itr: 11	Epoch: 5	Train Acc: 0.9359166666666666	Test Acc: 0.9789
# Itr: 11	Epoch: 6	Train Acc: 0.9429	Test Acc: 0.9814
# Itr: 11	Epoch: 7	Train Acc: 0.94925	Test Acc: 0.9827
# Itr: 11	Epoch: 8	Train Acc: 0.9507	Test Acc: 0.9835
# Itr: 11	Epoch: 9	Train Acc: 0.9546166666666667	Test Acc: 0.9838
# Itr: 11	Epoch: 10	Train Acc: 0.9575833333333333	Test Acc: 0.9852
# Itr: 11	Epoch: 11	Train Acc: 0.9597	Test Acc: 0.986
# Itr: 11	Epoch: 12	Train Acc: 0.9624833333333334	Test Acc: 0.9857
# Itr: 11	Epoch: 13	Train Acc: 0.9643166666666667	Test Acc: 0.9871
# Itr: 11	Epoch: 14	Train Acc: 0.9659833333333333	Test Acc: 0.9877
# Itr: 11	Epoch: 15	Train Acc: 0.9663333333333334	Test Acc: 0.9875
# Itr: 11	Epoch: 16	Train Acc: 0.9687166666666667	Test Acc: 0.9875
# Itr: 11	Epoch: 17	Train Acc: 0.9686833333333333	Test Acc: 0.9878
# Itr: 11	Epoch: 18	Train Acc: 0.9707833333333333	Test Acc: 0.9886
# Itr: 11	Epoch: 19	Train Acc: 0.9711666666666666	Test Acc: 0.9884
# Itr: 11	Epoch: 20	Train Acc: 0.9721333333333333	Test Acc: 0.9889
# Itr: 11	Epoch: 21	Train Acc: 0.9732	Test Acc: 0.9879
# Itr: 11	Epoch: 22	Train Acc: 0.9739	Test Acc: 0.9896
# Itr: 11	Epoch: 23	Train Acc: 0.9744666666666667	Test Acc: 0.99
# Itr: 11	Epoch: 24	Train Acc: 0.9752166666666666	Test Acc: 0.9906
# Itr: 11	Epoch: 25	Train Acc: 0.97575	Test Acc: 0.9907
# Itr: 11	Epoch: 26	Train Acc: 0.97675	Test Acc: 0.9911
# Itr: 11	Epoch: 27	Train Acc: 0.9767166666666667	Test Acc: 0.9914
# Itr: 11	Epoch: 28	Train Acc: 0.9777666666666667	Test Acc: 0.9906
# Itr: 11	Epoch: 29	Train Acc: 0.9784	Test Acc: 0.9916
# Itr: 11	Epoch: 30	Train Acc: 0.9785666666666667	Test Acc: 0.9912
# Itr: 11	Epoch: 31	Train Acc: 0.9793	Test Acc: 0.9917
# Itr: 11	Epoch: 32	Train Acc: 0.9801	Test Acc: 0.9919
# Itr: 11	Epoch: 33	Train Acc: 0.9798166666666667	Test Acc: 0.9918
# Itr: 11	Epoch: 34	Train Acc: 0.9800833333333333	Test Acc: 0.9916
# Itr: 11	Epoch: 35	Train Acc: 0.9807166666666667	Test Acc: 0.9922
# Itr: 11	Epoch: 36	Train Acc: 0.9820166666666666	Test Acc: 0.9918
# Itr: 11	Epoch: 37	Train Acc: 0.9811	Test Acc: 0.9924
# Itr: 11	Epoch: 38	Train Acc: 0.98125	Test Acc: 0.9922
# Itr: 11	Epoch: 39	Train Acc: 0.9823333333333333	Test Acc: 0.9927
# Itr: 11	Epoch: 40	Train Acc: 0.9822	Test Acc: 0.9927
# Itr: 11	Epoch: 41	Train Acc: 0.9823	Test Acc: 0.9923
# Itr: 11	Epoch: 42	Train Acc: 0.9828666666666667	Test Acc: 0.9931
# Itr: 11	Epoch: 43	Train Acc: 0.9829333333333333	Test Acc: 0.9928
# Itr: 11	Epoch: 44	Train Acc: 0.98295	Test Acc: 0.9928
# Itr: 11	Epoch: 45	Train Acc: 0.9835166666666667	Test Acc: 0.9932
# Itr: 11	Epoch: 46	Train Acc: 0.9834	Test Acc: 0.9925
# Itr: 11	Epoch: 47	Train Acc: 0.98415	Test Acc: 0.9928
# Itr: 11	Epoch: 48	Train Acc: 0.9842833333333333	Test Acc: 0.9934
# Itr: 11	Epoch: 49	Train Acc: 0.9839666666666667	Test Acc: 0.993
# Itr: 12	Epoch: 0	Train Acc: 0.7120333333333333	Test Acc: 0.9412
# Itr: 12	Epoch: 1	Train Acc: 0.8634833333333334	Test Acc: 0.9566
# Itr: 12	Epoch: 2	Train Acc: 0.9001166666666667	Test Acc: 0.9703
# Itr: 12	Epoch: 3	Train Acc: 0.9173	Test Acc: 0.9732
# Itr: 12	Epoch: 4	Train Acc: 0.9288833333333333	Test Acc: 0.9781
# Itr: 12	Epoch: 5	Train Acc: 0.9359166666666666	Test Acc: 0.9812
# Itr: 12	Epoch: 6	Train Acc: 0.9437666666666666	Test Acc: 0.9813
# Itr: 12	Epoch: 7	Train Acc: 0.9470666666666666	Test Acc: 0.9828
# Itr: 12	Epoch: 8	Train Acc: 0.9493333333333334	Test Acc: 0.9833
# Itr: 12	Epoch: 9	Train Acc: 0.9540666666666666	Test Acc: 0.985
# Itr: 12	Epoch: 10	Train Acc: 0.95705	Test Acc: 0.9853
# Itr: 12	Epoch: 11	Train Acc: 0.9604833333333334	Test Acc: 0.9847
# Itr: 12	Epoch: 12	Train Acc: 0.9618166666666667	Test Acc: 0.9848
# Itr: 12	Epoch: 13	Train Acc: 0.9633666666666667	Test Acc: 0.9876
# Itr: 12	Epoch: 14	Train Acc: 0.9660166666666666	Test Acc: 0.9873
# Itr: 12	Epoch: 15	Train Acc: 0.96505	Test Acc: 0.9888
# Itr: 12	Epoch: 16	Train Acc: 0.96815	Test Acc: 0.9878
# Itr: 12	Epoch: 17	Train Acc: 0.9701166666666666	Test Acc: 0.9884
# Itr: 12	Epoch: 18	Train Acc: 0.96905	Test Acc: 0.9893
# Itr: 12	Epoch: 19	Train Acc: 0.9710833333333333	Test Acc: 0.9884
# Itr: 12	Epoch: 20	Train Acc: 0.9720833333333333	Test Acc: 0.9894
# Itr: 12	Epoch: 21	Train Acc: 0.9728166666666667	Test Acc: 0.9887
# Itr: 12	Epoch: 22	Train Acc: 0.9725666666666667	Test Acc: 0.9901
# Itr: 12	Epoch: 23	Train Acc: 0.9747333333333333	Test Acc: 0.9901
# Itr: 12	Epoch: 24	Train Acc: 0.9754666666666667	Test Acc: 0.9901
# Itr: 12	Epoch: 25	Train Acc: 0.9757166666666667	Test Acc: 0.9906
# Itr: 12	Epoch: 26	Train Acc: 0.9766	Test Acc: 0.9912
# Itr: 12	Epoch: 27	Train Acc: 0.97655	Test Acc: 0.9905
# Itr: 12	Epoch: 28	Train Acc: 0.9770666666666666	Test Acc: 0.9912
# Itr: 12	Epoch: 29	Train Acc: 0.9770833333333333	Test Acc: 0.9916
# Itr: 12	Epoch: 30	Train Acc: 0.9784166666666667	Test Acc: 0.9911
# Itr: 12	Epoch: 31	Train Acc: 0.9782166666666666	Test Acc: 0.9917
# Itr: 12	Epoch: 32	Train Acc: 0.9789	Test Acc: 0.9919
# Itr: 12	Epoch: 33	Train Acc: 0.9795	Test Acc: 0.9916
# Itr: 12	Epoch: 34	Train Acc: 0.9791666666666666	Test Acc: 0.992
# Itr: 12	Epoch: 35	Train Acc: 0.9810833333333333	Test Acc: 0.9918
# Itr: 12	Epoch: 36	Train Acc: 0.9805666666666667	Test Acc: 0.9922
# Itr: 12	Epoch: 37	Train Acc: 0.9815	Test Acc: 0.9925
# Itr: 12	Epoch: 38	Train Acc: 0.9809	Test Acc: 0.9922
# Itr: 12	Epoch: 39	Train Acc: 0.9808666666666667	Test Acc: 0.9923
# Itr: 12	Epoch: 40	Train Acc: 0.9816833333333334	Test Acc: 0.9932
# Itr: 12	Epoch: 41	Train Acc: 0.9819	Test Acc: 0.9931
# Itr: 12	Epoch: 42	Train Acc: 0.9824	Test Acc: 0.9927
# Itr: 12	Epoch: 43	Train Acc: 0.9818166666666667	Test Acc: 0.9931
# Itr: 12	Epoch: 44	Train Acc: 0.9829333333333333	Test Acc: 0.993
# Itr: 12	Epoch: 45	Train Acc: 0.9827	Test Acc: 0.9933
# Itr: 12	Epoch: 46	Train Acc: 0.9829	Test Acc: 0.9933
# Itr: 12	Epoch: 47	Train Acc: 0.9837333333333333	Test Acc: 0.993
# Itr: 12	Epoch: 48	Train Acc: 0.9834333333333334	Test Acc: 0.9933
# Itr: 12	Epoch: 49	Train Acc: 0.98425	Test Acc: 0.994
# Itr: 13	Epoch: 0	Train Acc: 0.7155	Test Acc: 0.9454
# Itr: 13	Epoch: 1	Train Acc: 0.8649	Test Acc: 0.9607
# Itr: 13	Epoch: 2	Train Acc: 0.8978166666666667	Test Acc: 0.9681
# Itr: 13	Epoch: 3	Train Acc: 0.9181	Test Acc: 0.975
# Itr: 13	Epoch: 4	Train Acc: 0.9301166666666667	Test Acc: 0.9775
# Itr: 13	Epoch: 5	Train Acc: 0.9369833333333333	Test Acc: 0.9787
# Itr: 13	Epoch: 6	Train Acc: 0.9446333333333333	Test Acc: 0.982
# Itr: 13	Epoch: 7	Train Acc: 0.9482833333333334	Test Acc: 0.984
# Itr: 13	Epoch: 8	Train Acc: 0.9519333333333333	Test Acc: 0.9839
# Itr: 13	Epoch: 9	Train Acc: 0.9544666666666667	Test Acc: 0.9856
# Itr: 13	Epoch: 10	Train Acc: 0.9568166666666666	Test Acc: 0.9855
# Itr: 13	Epoch: 11	Train Acc: 0.9615	Test Acc: 0.9863
# Itr: 13	Epoch: 12	Train Acc: 0.9619166666666666	Test Acc: 0.9861
# Itr: 13	Epoch: 13	Train Acc: 0.9639166666666666	Test Acc: 0.9876
# Itr: 13	Epoch: 14	Train Acc: 0.9667333333333333	Test Acc: 0.9874
# Itr: 13	Epoch: 15	Train Acc: 0.9679333333333333	Test Acc: 0.9883
# Itr: 13	Epoch: 16	Train Acc: 0.9688	Test Acc: 0.9888
# Itr: 13	Epoch: 17	Train Acc: 0.9688833333333333	Test Acc: 0.9885
# Itr: 13	Epoch: 18	Train Acc: 0.9705833333333334	Test Acc: 0.9898
# Itr: 13	Epoch: 19	Train Acc: 0.9714	Test Acc: 0.99
# Itr: 13	Epoch: 20	Train Acc: 0.97285	Test Acc: 0.9899
# Itr: 13	Epoch: 21	Train Acc: 0.9737166666666667	Test Acc: 0.9905
# Itr: 13	Epoch: 22	Train Acc: 0.9749166666666667	Test Acc: 0.9903
# Itr: 13	Epoch: 23	Train Acc: 0.9751166666666666	Test Acc: 0.9902
# Itr: 13	Epoch: 24	Train Acc: 0.9752833333333333	Test Acc: 0.991
# Itr: 13	Epoch: 25	Train Acc: 0.9756166666666667	Test Acc: 0.9909
# Itr: 13	Epoch: 26	Train Acc: 0.9770166666666666	Test Acc: 0.9904
# Itr: 13	Epoch: 27	Train Acc: 0.9778333333333333	Test Acc: 0.9915
# Itr: 13	Epoch: 28	Train Acc: 0.9772166666666666	Test Acc: 0.9913
# Itr: 13	Epoch: 29	Train Acc: 0.9779166666666667	Test Acc: 0.9918
# Itr: 13	Epoch: 30	Train Acc: 0.9787666666666667	Test Acc: 0.9915
# Itr: 13	Epoch: 31	Train Acc: 0.97935	Test Acc: 0.992
# Itr: 13	Epoch: 32	Train Acc: 0.9797833333333333	Test Acc: 0.9913
# Itr: 13	Epoch: 33	Train Acc: 0.9805333333333334	Test Acc: 0.9922
# Itr: 13	Epoch: 34	Train Acc: 0.9803833333333334	Test Acc: 0.9914
# Itr: 13	Epoch: 35	Train Acc: 0.98075	Test Acc: 0.9923
# Itr: 13	Epoch: 36	Train Acc: 0.9804833333333334	Test Acc: 0.9924
# Itr: 13	Epoch: 37	Train Acc: 0.98155	Test Acc: 0.9926
# Itr: 13	Epoch: 38	Train Acc: 0.9816833333333334	Test Acc: 0.9919
# Itr: 13	Epoch: 39	Train Acc: 0.98185	Test Acc: 0.9936
# Itr: 13	Epoch: 40	Train Acc: 0.9824833333333334	Test Acc: 0.9923
# Itr: 13	Epoch: 41	Train Acc: 0.9825833333333334	Test Acc: 0.9935
# Itr: 13	Epoch: 42	Train Acc: 0.98235	Test Acc: 0.9932
# Itr: 13	Epoch: 43	Train Acc: 0.9831166666666666	Test Acc: 0.9931
# Itr: 13	Epoch: 44	Train Acc: 0.9830666666666666	Test Acc: 0.9936
# Itr: 13	Epoch: 45	Train Acc: 0.9838333333333333	Test Acc: 0.9934
# Itr: 13	Epoch: 46	Train Acc: 0.9837666666666667	Test Acc: 0.993
# Itr: 13	Epoch: 47	Train Acc: 0.9833666666666666	Test Acc: 0.993
# Itr: 13	Epoch: 48	Train Acc: 0.9838	Test Acc: 0.9934
# Itr: 13	Epoch: 49	Train Acc: 0.98425	Test Acc: 0.993
# Itr: 14	Epoch: 0	Train Acc: 0.69995	Test Acc: 0.9341
# Itr: 14	Epoch: 1	Train Acc: 0.8594333333333334	Test Acc: 0.959
# Itr: 14	Epoch: 2	Train Acc: 0.89615	Test Acc: 0.9684
# Itr: 14	Epoch: 3	Train Acc: 0.91595	Test Acc: 0.9732
# Itr: 14	Epoch: 4	Train Acc: 0.92705	Test Acc: 0.9747
# Itr: 14	Epoch: 5	Train Acc: 0.93275	Test Acc: 0.9783
# Itr: 14	Epoch: 6	Train Acc: 0.9410166666666666	Test Acc: 0.9791
# Itr: 14	Epoch: 7	Train Acc: 0.9461333333333334	Test Acc: 0.9822
# Itr: 14	Epoch: 8	Train Acc: 0.9506166666666667	Test Acc: 0.9824
# Itr: 14	Epoch: 9	Train Acc: 0.95275	Test Acc: 0.9838
# Itr: 14	Epoch: 10	Train Acc: 0.95725	Test Acc: 0.986
# Itr: 14	Epoch: 11	Train Acc: 0.9593	Test Acc: 0.9849
# Itr: 14	Epoch: 12	Train Acc: 0.9610166666666666	Test Acc: 0.9864
# Itr: 14	Epoch: 13	Train Acc: 0.96275	Test Acc: 0.9877
# Itr: 14	Epoch: 14	Train Acc: 0.9641666666666666	Test Acc: 0.9877
# Itr: 14	Epoch: 15	Train Acc: 0.9651666666666666	Test Acc: 0.9887
# Itr: 14	Epoch: 16	Train Acc: 0.9677166666666667	Test Acc: 0.9889
# Itr: 14	Epoch: 17	Train Acc: 0.9689833333333333	Test Acc: 0.9868
# Itr: 14	Epoch: 18	Train Acc: 0.96915	Test Acc: 0.9891
# Itr: 14	Epoch: 19	Train Acc: 0.9703666666666667	Test Acc: 0.9888
# Itr: 14	Epoch: 20	Train Acc: 0.9718666666666667	Test Acc: 0.9893
# Itr: 14	Epoch: 21	Train Acc: 0.9731166666666666	Test Acc: 0.9893
# Itr: 14	Epoch: 22	Train Acc: 0.9739666666666666	Test Acc: 0.9894
# Itr: 14	Epoch: 23	Train Acc: 0.97425	Test Acc: 0.9905
# Itr: 14	Epoch: 24	Train Acc: 0.9746666666666667	Test Acc: 0.9903
# Itr: 14	Epoch: 25	Train Acc: 0.9757666666666667	Test Acc: 0.9907
# Itr: 14	Epoch: 26	Train Acc: 0.9759666666666666	Test Acc: 0.9902
# Itr: 14	Epoch: 27	Train Acc: 0.97655	Test Acc: 0.9906
# Itr: 14	Epoch: 28	Train Acc: 0.9774666666666667	Test Acc: 0.9906
# Itr: 14	Epoch: 29	Train Acc: 0.9771	Test Acc: 0.991
# Itr: 14	Epoch: 30	Train Acc: 0.9788666666666667	Test Acc: 0.9911
# Itr: 14	Epoch: 31	Train Acc: 0.97795	Test Acc: 0.991
# Itr: 14	Epoch: 32	Train Acc: 0.9779166666666667	Test Acc: 0.9913
# Itr: 14	Epoch: 33	Train Acc: 0.9792166666666666	Test Acc: 0.9912
# Itr: 14	Epoch: 34	Train Acc: 0.9791833333333333	Test Acc: 0.991
# Itr: 14	Epoch: 35	Train Acc: 0.9800333333333333	Test Acc: 0.9919
# Itr: 14	Epoch: 36	Train Acc: 0.9802	Test Acc: 0.9916
# Itr: 14	Epoch: 37	Train Acc: 0.9810333333333333	Test Acc: 0.9923
# Itr: 14	Epoch: 38	Train Acc: 0.9814666666666667	Test Acc: 0.9928
# Itr: 14	Epoch: 39	Train Acc: 0.98115	Test Acc: 0.9924
# Itr: 14	Epoch: 40	Train Acc: 0.9816666666666667	Test Acc: 0.9925
# Itr: 14	Epoch: 41	Train Acc: 0.9823166666666666	Test Acc: 0.9924
# Itr: 14	Epoch: 42	Train Acc: 0.9818666666666667	Test Acc: 0.9932
# Itr: 14	Epoch: 43	Train Acc: 0.98235	Test Acc: 0.9924
# Itr: 14	Epoch: 44	Train Acc: 0.9825666666666667	Test Acc: 0.9921
# Itr: 14	Epoch: 45	Train Acc: 0.9829	Test Acc: 0.9924
# Itr: 14	Epoch: 46	Train Acc: 0.9828	Test Acc: 0.9925
# Itr: 14	Epoch: 47	Train Acc: 0.9834	Test Acc: 0.9934
# Itr: 14	Epoch: 48	Train Acc: 0.9835166666666667	Test Acc: 0.9923
# Itr: 14	Epoch: 49	Train Acc: 0.9837166666666667	Test Acc: 0.9933
# Itr: 15	Epoch: 0	Train Acc: 0.7121333333333333	Test Acc: 0.9432
# Itr: 15	Epoch: 1	Train Acc: 0.8618666666666667	Test Acc: 0.9625
# Itr: 15	Epoch: 2	Train Acc: 0.8983666666666666	Test Acc: 0.9683
# Itr: 15	Epoch: 3	Train Acc: 0.9173333333333333	Test Acc: 0.976
# Itr: 15	Epoch: 4	Train Acc: 0.92825	Test Acc: 0.9787
# Itr: 15	Epoch: 5	Train Acc: 0.9372833333333334	Test Acc: 0.9787
# Itr: 15	Epoch: 6	Train Acc: 0.9424666666666667	Test Acc: 0.9825
# Itr: 15	Epoch: 7	Train Acc: 0.94865	Test Acc: 0.9828
# Itr: 15	Epoch: 8	Train Acc: 0.95285	Test Acc: 0.9839
# Itr: 15	Epoch: 9	Train Acc: 0.9555833333333333	Test Acc: 0.983
# Itr: 15	Epoch: 10	Train Acc: 0.9581333333333333	Test Acc: 0.986
# Itr: 15	Epoch: 11	Train Acc: 0.9606	Test Acc: 0.9863
# Itr: 15	Epoch: 12	Train Acc: 0.9620333333333333	Test Acc: 0.9862
# Itr: 15	Epoch: 13	Train Acc: 0.9638833333333333	Test Acc: 0.9883
# Itr: 15	Epoch: 14	Train Acc: 0.96545	Test Acc: 0.9877
# Itr: 15	Epoch: 15	Train Acc: 0.9672833333333334	Test Acc: 0.9881
# Itr: 15	Epoch: 16	Train Acc: 0.9683333333333334	Test Acc: 0.9881
# Itr: 15	Epoch: 17	Train Acc: 0.9694833333333334	Test Acc: 0.9891
# Itr: 15	Epoch: 18	Train Acc: 0.972	Test Acc: 0.9897
# Itr: 15	Epoch: 19	Train Acc: 0.9716166666666667	Test Acc: 0.9898
# Itr: 15	Epoch: 20	Train Acc: 0.9724166666666667	Test Acc: 0.9892
# Itr: 15	Epoch: 21	Train Acc: 0.9735833333333334	Test Acc: 0.9897
# Itr: 15	Epoch: 22	Train Acc: 0.975	Test Acc: 0.9899
# Itr: 15	Epoch: 23	Train Acc: 0.97415	Test Acc: 0.9908
# Itr: 15	Epoch: 24	Train Acc: 0.9749833333333333	Test Acc: 0.9905
# Itr: 15	Epoch: 25	Train Acc: 0.9767333333333333	Test Acc: 0.9911
# ...
# Itr: 43	Epoch: 38	Train Acc: 0.9810666666666666	Test Acc: 0.9924
# Itr: 43	Epoch: 39	Train Acc: 0.98135	Test Acc: 0.9928
# Itr: 43	Epoch: 40	Train Acc: 0.9822833333333333	Test Acc: 0.9926
# Itr: 43	Epoch: 41	Train Acc: 0.982	Test Acc: 0.9926
# Itr: 43	Epoch: 42	Train Acc: 0.98205	Test Acc: 0.9935
# Itr: 43	Epoch: 43	Train Acc: 0.9822333333333333	Test Acc: 0.9928
# Itr: 43	Epoch: 44	Train Acc: 0.9817833333333333	Test Acc: 0.9933
# Itr: 43	Epoch: 45	Train Acc: 0.9828	Test Acc: 0.993
# Itr: 43	Epoch: 46	Train Acc: 0.9832	Test Acc: 0.9933
# Itr: 43	Epoch: 47	Train Acc: 0.9837166666666667	Test Acc: 0.9931
# Itr: 43	Epoch: 48	Train Acc: 0.9836666666666667	Test Acc: 0.9934
# Itr: 43	Epoch: 49	Train Acc: 0.9836666666666667	Test Acc: 0.9934
# Itr: 44	Epoch: 0	Train Acc: 0.7095166666666667	Test Acc: 0.9425
# Itr: 44	Epoch: 1	Train Acc: 0.8585333333333334	Test Acc: 0.957
# Itr: 44	Epoch: 2	Train Acc: 0.8928	Test Acc: 0.967
# Itr: 44	Epoch: 3	Train Acc: 0.91495	Test Acc: 0.9732
# Itr: 44	Epoch: 4	Train Acc: 0.9237666666666666	Test Acc: 0.9773
# Itr: 44	Epoch: 5	Train Acc: 0.9348166666666666	Test Acc: 0.9808
# Itr: 44	Epoch: 6	Train Acc: 0.9410666666666667	Test Acc: 0.9781
# Itr: 44	Epoch: 7	Train Acc: 0.9446666666666667	Test Acc: 0.9823
# Itr: 44	Epoch: 8	Train Acc: 0.9506166666666667	Test Acc: 0.9848
# Itr: 44	Epoch: 9	Train Acc: 0.95375	Test Acc: 0.985
# Itr: 44	Epoch: 10	Train Acc: 0.95725	Test Acc: 0.9853
# Itr: 44	Epoch: 11	Train Acc: 0.9592166666666667	Test Acc: 0.9872
# Itr: 44	Epoch: 12	Train Acc: 0.96095	Test Acc: 0.9859
# Itr: 44	Epoch: 13	Train Acc: 0.9624333333333334	Test Acc: 0.9874
# Itr: 44	Epoch: 14	Train Acc: 0.9646833333333333	Test Acc: 0.988
# Itr: 44	Epoch: 15	Train Acc: 0.9667833333333333	Test Acc: 0.988
# Itr: 44	Epoch: 16	Train Acc: 0.9673333333333334	Test Acc: 0.9892
# Itr: 44	Epoch: 17	Train Acc: 0.9675333333333334	Test Acc: 0.9893
# Itr: 44	Epoch: 18	Train Acc: 0.96925	Test Acc: 0.9877
# Itr: 44	Epoch: 19	Train Acc: 0.9708166666666667	Test Acc: 0.9893
# Itr: 44	Epoch: 20	Train Acc: 0.9723666666666667	Test Acc: 0.9904
# Itr: 44	Epoch: 21	Train Acc: 0.9729	Test Acc: 0.9908
# Itr: 44	Epoch: 22	Train Acc: 0.9737333333333333	Test Acc: 0.9907
# Itr: 44	Epoch: 23	Train Acc: 0.9738833333333333	Test Acc: 0.9905
# Itr: 44	Epoch: 24	Train Acc: 0.9752166666666666	Test Acc: 0.9906
# Itr: 44	Epoch: 25	Train Acc: 0.9753833333333334	Test Acc: 0.9912
# Itr: 44	Epoch: 26	Train Acc: 0.97645	Test Acc: 0.9912
# Itr: 44	Epoch: 27	Train Acc: 0.9756833333333333	Test Acc: 0.991
# Itr: 44	Epoch: 28	Train Acc: 0.9776333333333334	Test Acc: 0.9921
# Itr: 44	Epoch: 29	Train Acc: 0.9781666666666666	Test Acc: 0.9918
# Itr: 44	Epoch: 30	Train Acc: 0.97795	Test Acc: 0.9923
# Itr: 44	Epoch: 31	Train Acc: 0.9793333333333333	Test Acc: 0.9918
# Itr: 44	Epoch: 32	Train Acc: 0.9793333333333333	Test Acc: 0.9922
# Itr: 44	Epoch: 33	Train Acc: 0.9791166666666666	Test Acc: 0.9916
# Itr: 44	Epoch: 34	Train Acc: 0.9798166666666667	Test Acc: 0.9923
# Itr: 44	Epoch: 35	Train Acc: 0.9799166666666667	Test Acc: 0.9918
# Itr: 44	Epoch: 36	Train Acc: 0.98065	Test Acc: 0.9925
# Itr: 44	Epoch: 37	Train Acc: 0.9811166666666666	Test Acc: 0.993
# Itr: 44	Epoch: 38	Train Acc: 0.981	Test Acc: 0.9924
# Itr: 44	Epoch: 39	Train Acc: 0.9813	Test Acc: 0.993
# Itr: 44	Epoch: 40	Train Acc: 0.98145	Test Acc: 0.9928
# Itr: 44	Epoch: 41	Train Acc: 0.9812666666666666	Test Acc: 0.9926
# Itr: 44	Epoch: 42	Train Acc: 0.9823	Test Acc: 0.993
# Itr: 44	Epoch: 43	Train Acc: 0.9827	Test Acc: 0.9933
# Itr: 44	Epoch: 44	Train Acc: 0.9831166666666666	Test Acc: 0.9936
# Itr: 44	Epoch: 45	Train Acc: 0.9827833333333333	Test Acc: 0.993
# Itr: 44	Epoch: 46	Train Acc: 0.9828333333333333	Test Acc: 0.9936
# Itr: 44	Epoch: 47	Train Acc: 0.9840333333333333	Test Acc: 0.9927
# Itr: 44	Epoch: 48	Train Acc: 0.9843	Test Acc: 0.994
# Itr: 44	Epoch: 49	Train Acc: 0.9839666666666667	Test Acc: 0.9935
# Itr: 45	Epoch: 0	Train Acc: 0.7082666666666667	Test Acc: 0.9376
# Itr: 45	Epoch: 1	Train Acc: 0.8637166666666667	Test Acc: 0.9611
# Itr: 45	Epoch: 2	Train Acc: 0.8961666666666667	Test Acc: 0.9676
# Itr: 45	Epoch: 3	Train Acc: 0.9147833333333333	Test Acc: 0.9716
# Itr: 45	Epoch: 4	Train Acc: 0.9265833333333333	Test Acc: 0.9772
# Itr: 45	Epoch: 5	Train Acc: 0.9334166666666667	Test Acc: 0.9783
# Itr: 45	Epoch: 6	Train Acc: 0.9392333333333334	Test Acc: 0.9809
# Itr: 45	Epoch: 7	Train Acc: 0.9457833333333333	Test Acc: 0.9828
# Itr: 45	Epoch: 8	Train Acc: 0.9497166666666667	Test Acc: 0.9826
# Itr: 45	Epoch: 9	Train Acc: 0.95265	Test Acc: 0.9842
# Itr: 45	Epoch: 10	Train Acc: 0.9542333333333334	Test Acc: 0.9851
# Itr: 45	Epoch: 11	Train Acc: 0.9574166666666667	Test Acc: 0.9858
# Itr: 45	Epoch: 12	Train Acc: 0.9611166666666666	Test Acc: 0.9873
# Itr: 45	Epoch: 13	Train Acc: 0.9611833333333333	Test Acc: 0.9864
# Itr: 45	Epoch: 14	Train Acc: 0.9641666666666666	Test Acc: 0.9882
# Itr: 45	Epoch: 15	Train Acc: 0.96485	Test Acc: 0.9884
# Itr: 45	Epoch: 16	Train Acc: 0.9663833333333334	Test Acc: 0.9884
# Itr: 45	Epoch: 17	Train Acc: 0.9668833333333333	Test Acc: 0.9876
# Itr: 45	Epoch: 18	Train Acc: 0.9684333333333334	Test Acc: 0.9885
# Itr: 45	Epoch: 19	Train Acc: 0.9702	Test Acc: 0.99
# Itr: 45	Epoch: 20	Train Acc: 0.9707666666666667	Test Acc: 0.9894
# Itr: 45	Epoch: 21	Train Acc: 0.972	Test Acc: 0.9904
# Itr: 45	Epoch: 22	Train Acc: 0.9730333333333333	Test Acc: 0.9897
# Itr: 45	Epoch: 23	Train Acc: 0.9728333333333333	Test Acc: 0.9903
# Itr: 45	Epoch: 24	Train Acc: 0.9735833333333334	Test Acc: 0.9884
# Itr: 45	Epoch: 25	Train Acc: 0.9745166666666667	Test Acc: 0.9911
# Itr: 45	Epoch: 26	Train Acc: 0.9747	Test Acc: 0.9911
# Itr: 45	Epoch: 27	Train Acc: 0.9762833333333333	Test Acc: 0.9911
# Itr: 45	Epoch: 28	Train Acc: 0.9763166666666667	Test Acc: 0.9913
# Itr: 45	Epoch: 29	Train Acc: 0.9767666666666667	Test Acc: 0.9907
# Itr: 45	Epoch: 30	Train Acc: 0.9778166666666667	Test Acc: 0.9919
# Itr: 45	Epoch: 31	Train Acc: 0.9782166666666666	Test Acc: 0.9922
# Itr: 45	Epoch: 32	Train Acc: 0.97825	Test Acc: 0.9918
# Itr: 45	Epoch: 33	Train Acc: 0.9782833333333333	Test Acc: 0.9918
# Itr: 45	Epoch: 34	Train Acc: 0.9792	Test Acc: 0.991
# Itr: 45	Epoch: 35	Train Acc: 0.9792333333333333	Test Acc: 0.9919
# Itr: 45	Epoch: 36	Train Acc: 0.9797666666666667	Test Acc: 0.9922
# Itr: 45	Epoch: 37	Train Acc: 0.9795333333333334	Test Acc: 0.9917
# Itr: 45	Epoch: 38	Train Acc: 0.9802833333333333	Test Acc: 0.9923
# Itr: 45	Epoch: 39	Train Acc: 0.9805833333333334	Test Acc: 0.9922
# Itr: 45	Epoch: 40	Train Acc: 0.9810833333333333	Test Acc: 0.9934
# Itr: 45	Epoch: 41	Train Acc: 0.98075	Test Acc: 0.993
# Itr: 45	Epoch: 42	Train Acc: 0.9811666666666666	Test Acc: 0.9926
# Itr: 45	Epoch: 43	Train Acc: 0.98205	Test Acc: 0.9928
# Itr: 45	Epoch: 44	Train Acc: 0.9823	Test Acc: 0.993
# Itr: 45	Epoch: 45	Train Acc: 0.9825166666666667	Test Acc: 0.9931
# Itr: 45	Epoch: 46	Train Acc: 0.9828833333333333	Test Acc: 0.993
# Itr: 45	Epoch: 47	Train Acc: 0.9832833333333333	Test Acc: 0.9926
# Itr: 45	Epoch: 48	Train Acc: 0.9828333333333333	Test Acc: 0.9929
# Itr: 45	Epoch: 49	Train Acc: 0.9835166666666667	Test Acc: 0.9931
# Itr: 46	Epoch: 0	Train Acc: 0.69775	Test Acc: 0.9303
# Itr: 46	Epoch: 1	Train Acc: 0.8594166666666667	Test Acc: 0.9605
# Itr: 46	Epoch: 2	Train Acc: 0.8948666666666667	Test Acc: 0.9669
# Itr: 46	Epoch: 3	Train Acc: 0.9149	Test Acc: 0.9718
# Itr: 46	Epoch: 4	Train Acc: 0.92705	Test Acc: 0.9768
# Itr: 46	Epoch: 5	Train Acc: 0.93475	Test Acc: 0.9797
# Itr: 46	Epoch: 6	Train Acc: 0.9404	Test Acc: 0.9815
# Itr: 46	Epoch: 7	Train Acc: 0.9466	Test Acc: 0.9833
# Itr: 46	Epoch: 8	Train Acc: 0.9505166666666667	Test Acc: 0.9834
# Itr: 46	Epoch: 9	Train Acc: 0.95285	Test Acc: 0.9857
# Itr: 46	Epoch: 10	Train Acc: 0.9565833333333333	Test Acc: 0.9847
# Itr: 46	Epoch: 11	Train Acc: 0.9589333333333333	Test Acc: 0.9859
# Itr: 46	Epoch: 12	Train Acc: 0.9609666666666666	Test Acc: 0.9852
# Itr: 46	Epoch: 13	Train Acc: 0.9629166666666666	Test Acc: 0.9876
# Itr: 46	Epoch: 14	Train Acc: 0.9645	Test Acc: 0.9857
# Itr: 46	Epoch: 15	Train Acc: 0.96585	Test Acc: 0.9872
# Itr: 46	Epoch: 16	Train Acc: 0.9669333333333333	Test Acc: 0.9882
# Itr: 46	Epoch: 17	Train Acc: 0.9689333333333333	Test Acc: 0.9885
# Itr: 46	Epoch: 18	Train Acc: 0.9688333333333333	Test Acc: 0.9887
# Itr: 46	Epoch: 19	Train Acc: 0.97005	Test Acc: 0.9883
# Itr: 46	Epoch: 20	Train Acc: 0.9719666666666666	Test Acc: 0.9895
# Itr: 46	Epoch: 21	Train Acc: 0.97235	Test Acc: 0.9897
# Itr: 46	Epoch: 22	Train Acc: 0.9723833333333334	Test Acc: 0.9887
# Itr: 46	Epoch: 23	Train Acc: 0.97375	Test Acc: 0.99
# Itr: 46	Epoch: 24	Train Acc: 0.9743666666666667	Test Acc: 0.9903
# Itr: 46	Epoch: 25	Train Acc: 0.9746666666666667	Test Acc: 0.9903
# Itr: 46	Epoch: 26	Train Acc: 0.9756	Test Acc: 0.9906
# Itr: 46	Epoch: 27	Train Acc: 0.9761666666666666	Test Acc: 0.9912
# Itr: 46	Epoch: 28	Train Acc: 0.9769333333333333	Test Acc: 0.9907
# Itr: 46	Epoch: 29	Train Acc: 0.97775	Test Acc: 0.9907
# Itr: 46	Epoch: 30	Train Acc: 0.9779	Test Acc: 0.9913
# Itr: 46	Epoch: 31	Train Acc: 0.97835	Test Acc: 0.9904
# Itr: 46	Epoch: 32	Train Acc: 0.9793833333333334	Test Acc: 0.9911
# Itr: 46	Epoch: 33	Train Acc: 0.9787333333333333	Test Acc: 0.9915
# Itr: 46	Epoch: 34	Train Acc: 0.9796833333333334	Test Acc: 0.9908
# Itr: 46	Epoch: 35	Train Acc: 0.9791833333333333	Test Acc: 0.9918
# Itr: 46	Epoch: 36	Train Acc: 0.98015	Test Acc: 0.9918
# Itr: 46	Epoch: 37	Train Acc: 0.9802333333333333	Test Acc: 0.9924
# Itr: 46	Epoch: 38	Train Acc: 0.9809	Test Acc: 0.9926
# Itr: 46	Epoch: 39	Train Acc: 0.9812	Test Acc: 0.9916
# Itr: 46	Epoch: 40	Train Acc: 0.9813333333333333	Test Acc: 0.992
# Itr: 46	Epoch: 41	Train Acc: 0.98165	Test Acc: 0.9921
# Itr: 46	Epoch: 42	Train Acc: 0.9822166666666666	Test Acc: 0.9927
# Itr: 46	Epoch: 43	Train Acc: 0.98245	Test Acc: 0.9927
# Itr: 46	Epoch: 44	Train Acc: 0.982	Test Acc: 0.9931
# Itr: 46	Epoch: 45	Train Acc: 0.9823666666666667	Test Acc: 0.9921
# Itr: 46	Epoch: 46	Train Acc: 0.9835666666666667	Test Acc: 0.9931
# Itr: 46	Epoch: 47	Train Acc: 0.9826166666666667	Test Acc: 0.9927
# Itr: 46	Epoch: 48	Train Acc: 0.9828333333333333	Test Acc: 0.9922
# Itr: 46	Epoch: 49	Train Acc: 0.9835833333333334	Test Acc: 0.9927
# Itr: 47	Epoch: 0	Train Acc: 0.71215	Test Acc: 0.9396
# Itr: 47	Epoch: 1	Train Acc: 0.8669166666666667	Test Acc: 0.9625
# Itr: 47	Epoch: 2	Train Acc: 0.9026	Test Acc: 0.9653
# Itr: 47	Epoch: 3	Train Acc: 0.91855	Test Acc: 0.9754
# Itr: 47	Epoch: 4	Train Acc: 0.9304833333333333	Test Acc: 0.9795
# Itr: 47	Epoch: 5	Train Acc: 0.9395833333333333	Test Acc: 0.9811
# Itr: 47	Epoch: 6	Train Acc: 0.9436833333333333	Test Acc: 0.983
# Itr: 47	Epoch: 7	Train Acc: 0.9484166666666667	Test Acc: 0.9842
# Itr: 47	Epoch: 8	Train Acc: 0.9532833333333334	Test Acc: 0.9851
# Itr: 47	Epoch: 9	Train Acc: 0.9565333333333333	Test Acc: 0.9861
# Itr: 47	Epoch: 10	Train Acc: 0.9590333333333333	Test Acc: 0.9867
# Itr: 47	Epoch: 11	Train Acc: 0.9613333333333334	Test Acc: 0.9873
# Itr: 47	Epoch: 12	Train Acc: 0.9631166666666666	Test Acc: 0.9877
# Itr: 47	Epoch: 13	Train Acc: 0.9650333333333333	Test Acc: 0.9882
# Itr: 47	Epoch: 14	Train Acc: 0.9674166666666667	Test Acc: 0.9886
# Itr: 47	Epoch: 15	Train Acc: 0.9683333333333334	Test Acc: 0.9892
# Itr: 47	Epoch: 16	Train Acc: 0.9684833333333334	Test Acc: 0.9895
# Itr: 47	Epoch: 17	Train Acc: 0.9710666666666666	Test Acc: 0.9896
# Itr: 47	Epoch: 18	Train Acc: 0.9719	Test Acc: 0.9904
# Itr: 47	Epoch: 19	Train Acc: 0.9729166666666667	Test Acc: 0.9903
# Itr: 47	Epoch: 20	Train Acc: 0.9738	Test Acc: 0.9902
# Itr: 47	Epoch: 21	Train Acc: 0.9742833333333333	Test Acc: 0.9903
# Itr: 47	Epoch: 22	Train Acc: 0.9753833333333334	Test Acc: 0.9901
# Itr: 47	Epoch: 23	Train Acc: 0.9760333333333333	Test Acc: 0.9913
# Itr: 47	Epoch: 24	Train Acc: 0.9757	Test Acc: 0.9914
# Itr: 47	Epoch: 25	Train Acc: 0.9764333333333334	Test Acc: 0.9917
# Itr: 47	Epoch: 26	Train Acc: 0.9773666666666667	Test Acc: 0.9922
# Itr: 47	Epoch: 27	Train Acc: 0.9774666666666667	Test Acc: 0.9923
# Itr: 47	Epoch: 28	Train Acc: 0.9781666666666666	Test Acc: 0.9918
# Itr: 47	Epoch: 29	Train Acc: 0.9788666666666667	Test Acc: 0.9918
# Itr: 47	Epoch: 30	Train Acc: 0.9797333333333333	Test Acc: 0.9928
# Itr: 47	Epoch: 31	Train Acc: 0.9795333333333334	Test Acc: 0.992
# Itr: 47	Epoch: 32	Train Acc: 0.9798166666666667	Test Acc: 0.9924
# Itr: 47	Epoch: 33	Train Acc: 0.98045	Test Acc: 0.9922
# Itr: 47	Epoch: 34	Train Acc: 0.9801666666666666	Test Acc: 0.9923
# Itr: 47	Epoch: 35	Train Acc: 0.9814333333333334	Test Acc: 0.9934
# Itr: 47	Epoch: 36	Train Acc: 0.9808333333333333	Test Acc: 0.9927
# Itr: 47	Epoch: 37	Train Acc: 0.9820333333333333	Test Acc: 0.9927
# Itr: 47	Epoch: 38	Train Acc: 0.98265	Test Acc: 0.993
# Itr: 47	Epoch: 39	Train Acc: 0.98205	Test Acc: 0.9929
# Itr: 47	Epoch: 40	Train Acc: 0.9825833333333334	Test Acc: 0.9931
# Itr: 47	Epoch: 41	Train Acc: 0.9831833333333333	Test Acc: 0.9932
# Itr: 47	Epoch: 42	Train Acc: 0.9829333333333333	Test Acc: 0.9929
# Itr: 47	Epoch: 43	Train Acc: 0.9834333333333334	Test Acc: 0.9933
# Itr: 47	Epoch: 44	Train Acc: 0.9842333333333333	Test Acc: 0.9928
# Itr: 47	Epoch: 45	Train Acc: 0.9836333333333334	Test Acc: 0.9933
# Itr: 47	Epoch: 46	Train Acc: 0.9837	Test Acc: 0.9933
# Itr: 47	Epoch: 47	Train Acc: 0.9841333333333333	Test Acc: 0.9939
# Itr: 47	Epoch: 48	Train Acc: 0.9842333333333333	Test Acc: 0.9935
# Itr: 47	Epoch: 49	Train Acc: 0.9847666666666667	Test Acc: 0.9937
# Itr: 48	Epoch: 0	Train Acc: 0.7155833333333333	Test Acc: 0.9346
# Itr: 48	Epoch: 1	Train Acc: 0.8638	Test Acc: 0.9611
# Itr: 48	Epoch: 2	Train Acc: 0.8985	Test Acc: 0.9695
# Itr: 48	Epoch: 3	Train Acc: 0.91575	Test Acc: 0.9738
# Itr: 48	Epoch: 4	Train Acc: 0.9268333333333333	Test Acc: 0.9762
# Itr: 48	Epoch: 5	Train Acc: 0.9356333333333333	Test Acc: 0.9802
# Itr: 48	Epoch: 6	Train Acc: 0.9416166666666667	Test Acc: 0.9806
# Itr: 48	Epoch: 7	Train Acc: 0.9456333333333333	Test Acc: 0.9821
# Itr: 48	Epoch: 8	Train Acc: 0.94965	Test Acc: 0.9815
# Itr: 48	Epoch: 9	Train Acc: 0.9525666666666667	Test Acc: 0.985
# Itr: 48	Epoch: 10	Train Acc: 0.9563	Test Acc: 0.9856
# Itr: 48	Epoch: 11	Train Acc: 0.9589333333333333	Test Acc: 0.9863
# Itr: 48	Epoch: 12	Train Acc: 0.9599	Test Acc: 0.9854
# Itr: 48	Epoch: 13	Train Acc: 0.96305	Test Acc: 0.9873
# Itr: 48	Epoch: 14	Train Acc: 0.96375	Test Acc: 0.9877
# Itr: 48	Epoch: 15	Train Acc: 0.96565	Test Acc: 0.9875
# Itr: 48	Epoch: 16	Train Acc: 0.96655	Test Acc: 0.9878
# Itr: 48	Epoch: 17	Train Acc: 0.9685666666666667	Test Acc: 0.9883
# Itr: 48	Epoch: 18	Train Acc: 0.9702666666666667	Test Acc: 0.9893
# Itr: 48	Epoch: 19	Train Acc: 0.97005	Test Acc: 0.9889
# Itr: 48	Epoch: 20	Train Acc: 0.9716	Test Acc: 0.9893
# Itr: 48	Epoch: 21	Train Acc: 0.9725333333333334	Test Acc: 0.9899
# Itr: 48	Epoch: 22	Train Acc: 0.97265	Test Acc: 0.99
# Itr: 48	Epoch: 23	Train Acc: 0.9735833333333334	Test Acc: 0.9902
# Itr: 48	Epoch: 24	Train Acc: 0.9732	Test Acc: 0.9907
# Itr: 48	Epoch: 25	Train Acc: 0.9756833333333333	Test Acc: 0.9902
# Itr: 48	Epoch: 26	Train Acc: 0.9754	Test Acc: 0.9901
# Itr: 48	Epoch: 27	Train Acc: 0.9762	Test Acc: 0.9912
# Itr: 48	Epoch: 28	Train Acc: 0.9762833333333333	Test Acc: 0.9905
# Itr: 48	Epoch: 29	Train Acc: 0.9782333333333333	Test Acc: 0.9912
# Itr: 48	Epoch: 30	Train Acc: 0.9772833333333333	Test Acc: 0.9913
# Itr: 48	Epoch: 31	Train Acc: 0.9786833333333333	Test Acc: 0.9915
# Itr: 48	Epoch: 32	Train Acc: 0.9789333333333333	Test Acc: 0.992
# Itr: 48	Epoch: 33	Train Acc: 0.97805	Test Acc: 0.9911
# Itr: 48	Epoch: 34	Train Acc: 0.97945	Test Acc: 0.9916
# Itr: 48	Epoch: 35	Train Acc: 0.9793166666666666	Test Acc: 0.9924
# Itr: 48	Epoch: 36	Train Acc: 0.9803833333333334	Test Acc: 0.9914
# Itr: 48	Epoch: 37	Train Acc: 0.9801166666666666	Test Acc: 0.9924
# Itr: 48	Epoch: 38	Train Acc: 0.9805666666666667	Test Acc: 0.9924
# Itr: 48	Epoch: 39	Train Acc: 0.9812333333333333	Test Acc: 0.9928
# Itr: 48	Epoch: 40	Train Acc: 0.9807333333333333	Test Acc: 0.9924
# Itr: 48	Epoch: 41	Train Acc: 0.9820833333333333	Test Acc: 0.9922
# Itr: 48	Epoch: 42	Train Acc: 0.98205	Test Acc: 0.9926
# Itr: 48	Epoch: 43	Train Acc: 0.9818	Test Acc: 0.993
# Itr: 48	Epoch: 44	Train Acc: 0.9823666666666667	Test Acc: 0.993
# Itr: 48	Epoch: 45	Train Acc: 0.9824166666666667	Test Acc: 0.993
# Itr: 48	Epoch: 46	Train Acc: 0.9831166666666666	Test Acc: 0.9932
# Itr: 48	Epoch: 47	Train Acc: 0.9827166666666667	Test Acc: 0.9922
# Itr: 48	Epoch: 48	Train Acc: 0.9823833333333334	Test Acc: 0.9932
# Itr: 48	Epoch: 49	Train Acc: 0.98385	Test Acc: 0.9934
